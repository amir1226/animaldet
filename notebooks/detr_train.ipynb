# %% [markdown]
# # Entrenamiento modelos RF-DETR

# %%
from dataclasses import asdict
from pathlib import Path
from shutil import copy2
import json

import albumentations as A
import numpy as np
import pandas as pd
import torch
from PIL import Image
from albumentations.pytorch import ToTensorV2
from omegaconf import OmegaConf
from tqdm import tqdm

from rfdetr import RFDETRLarge

from utils.common.bbox import convert_bbox_csv_to_points
from utils.herdnet import evaluate_points_from_csv
from utils.rf_detr import (
    DEFAULT_CATEGORIES,
    Detection,
    DetectionSample,
    HerdNetMetricsCallback,
    PatchSummary,
    SimpleStitcher,
    generate_patch_dataset,
    write_coco_predictions,
)
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 2.0.8 (you have 1.4.8). Upgrade using: pip install --upgrade albumentations

# %% [markdown]
# ## Fase 0 — Generación de Parches
#
# Dividimos las imágenes 24MP en parches cuadráticos y ajustamos las anotaciones COCO para obtener el dataset de entrenamiento.
#
# ### Configuración Inicial
# Constantes a utilizar durante el entrenamiento y carpetas de destino para los parches generados

# %%
PATCH_SIZE = 560
PATCH_OVERLAP = 160
IMG_NORMALIZE_MEAN = [0.485, 0.456, 0.406]
IMG_NORMALIZE_STD = [0.229, 0.224, 0.225]
TRAIN_EPOCHS = 50
BATCH_SIZE = 16
GRAD_ACCUM_STEPS = 4
CONF_THRESHOLD_STAGE1 = 0.5
CONF_THRESHOLD_STAGE2 = 0.5
MATCH_RADIUS = 20.0

# %%
patch_jobs = [
    {
        'split': 'train',
        'images_dir': 'data-delplanque/train',
        'json_file': 'data-delplanque/groundtruth/json/train.json',
        'output_dir': 'data-large-detr/train',
        'patch_width': PATCH_SIZE,
        'patch_height': PATCH_SIZE,
        'overlap': PATCH_OVERLAP,
        'min_visibility': 0.8,
    },
    {
        'split': 'valid',
        'images_dir': 'data-delplanque/val',
        'json_file': 'data-delplanque/groundtruth/json/val.json',
        'output_dir': 'data-large-detr/valid',
        'patch_width': PATCH_SIZE,
        'patch_height': PATCH_SIZE,
        'overlap': PATCH_OVERLAP,
        'min_visibility': 0.8,
    },
]

# %% [markdown]
# Generación de parches y archivo con los groundtruth ajustados para la escala de parches. Los parches corresponden a únicamente aquellos que cuentan con animales

# %%
patch_summaries = []
for job in patch_jobs:
    summary = generate_patch_dataset(
        images_dir=job['images_dir'],
        json_file=job['json_file'],
        output_dir=job['output_dir'],
        patch_width=job['patch_width'],
        patch_height=job['patch_height'],
        overlap=job['overlap'],
        min_visibility=job['min_visibility'],
    )
    entry = {'split': job['split']}
    entry.update(asdict(summary))
    patch_summaries.append(entry)

pd.DataFrame(patch_summaries)

# %% [markdown]
# ## Fase 1 — Entrenamiento Inicial RF-DETR
#
# Entrenamos el flavor de RF-DETR sobre los parches generados (con animales) y registramos métricas de HerdNet (callback) durante el entrenamiento.

# %% [markdown]
# ### Inicializar modelo y callback

# %%
model = RFDETRLarge()

herdnet_callback = HerdNetMetricsCallback(
    model=model,
    val_dataset_path='data-large-detr/valid/_annotations.coco.json',
    val_images_dir='data-large-detr/valid',
    threshold_px=20,
    confidence_threshold=0.5,
    wandb_log=True,
    eval_every_n_epochs=5,
)

model.callbacks['on_fit_epoch_end'].append(herdnet_callback.update)

# %% [markdown]
# ### Entrenamiento

# %%
model.train(
    dataset_dir='data-large-detr',
    dataset_file='roboflow',
    img_size=PATCH_SIZE,
    epochs=TRAIN_EPOCHS,
    batch_size=BATCH_SIZE,
    grad_accum_steps=GRAD_ACCUM_STEPS,
    output_dir='outputs/rfdetr_large_stage1',
    wandb=True,
    project='rf-detr-large',
)

# %% [markdown]
# ### Evaluación

# %% [markdown]
# #### Configuración de inferencia y métricas

# %%
eval_cfg = OmegaConf.create({
    'data': {
        'images_root': 'data-delplanque/test',
        'gt_points_csv': 'data-delplanque/test.csv',
    },
    'inference': {
        'device': 'cuda',
        'checkpoint_path': './outputs/rfdetr_large_2/checkpoint_best_total.pth',
        'threshold': CONF_THRESHOLD_STAGE1,
        'batch_size': 16,
        'output_path': './results/rfdetr_large',
        'detections_csv': 'rfdetr_stage1_detections.csv',
    },
    'metrics': {
        'radius': MATCH_RADIUS,
        'class_map': None,
    },
})

# %% [markdown]
# #### Cargar checkpoint y preparar stitcher
# Se carga el checkpoint del modelo con el mejor resultado sobre el conjunto de validación y se carga el stitcher, el cual se encargará de hacer las predicciones en cada parche del tamaño definido en ventana deslizante, asegurandosé de escalar las detecciones a las coordenas en la imagen original de 24MP.

# %%
checkpoint = torch.load(eval_cfg.inference.checkpoint_path, weights_only=False)
state_dict = checkpoint.get('model', checkpoint.get('ema_model'))
num_classes = state_dict['class_embed.weight'].shape[0]

model_eval = RFDETRLarge()
model_eval.model.reinitialize_detection_head(num_classes)
model_eval.model.model.load_state_dict(state_dict, strict=True)
model_eval.model.model.to(eval_cfg.inference.device).eval()

stitcher = SimpleStitcher(
    model=model_eval.model.model,
    patch_size=PATCH_SIZE,
    overlap=0,
    batch_size=eval_cfg.inference.batch_size,
    confidence_threshold=eval_cfg.inference.threshold,
    device=eval_cfg.inference.device,
    label_offset=0,
)
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights

# %% [markdown]
# #### Ejecutar inferencia sobre imágenes completas

# %%
from pathlib import Path


images_root = Path(eval_cfg.data.images_root)
image_files = sorted(
    list(images_root.glob('*.jpg'))
    + list(images_root.glob('*.JPG'))
    + list(images_root.glob('*.png'))
    + list[Path](images_root.glob('*.PNG'))
)

transform = A.Compose([
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

output_dir = Path(eval_cfg.inference.output_path)
output_dir.mkdir(parents=True, exist_ok=True)
all_detections = []

for img_path in tqdm(image_files, desc='Inference'):
    image = Image.open(img_path).convert('RGB')
    image_tensor = transform(image=np.array(image))['image']
    detections = stitcher(image_tensor)

    for i in range(len(detections['scores'])):
        all_detections.append({
            'images': img_path.name,
            'x': float(detections['boxes'][i, 0]),
            'y': float(detections['boxes'][i, 1]),
            'x_max': float(detections['boxes'][i, 2]),
            'y_max': float(detections['boxes'][i, 3]),
            'labels': int(detections['labels'][i]),
            'scores': float(detections['scores'][i]),
        })

pd.DataFrame(all_detections).to_csv(output_dir / eval_cfg.inference.detections_csv, index=False)
print('Saved', len(all_detections), 'detections to', output_dir / eval_cfg.inference.detections_csv)
# Out:
# Inference: 100%|██████████| 258/258 [03:19<00:00,  1.30it/s]
# Saved 4292 detections to results/rfdetr_nano/rfdetr_stage1_detections.csv

# %% [markdown]
# #### Convertir detecciones a puntos
#
# Debido a que los modelos RF-DETR generán bounding boxes para las detecciones, se calculán su centroides para calcular las métricas y poder comparar con los resultados de HerdNet.

# %%
points_path = output_dir / 'rfdetr_stage1_detections_points.csv'
points_df = convert_bbox_csv_to_points(
    output_dir / eval_cfg.inference.detections_csv,
    points_path,
)
print('Converted', len(points_df), 'detections to points ->', points_path)
points_df.head()
# Out:
# Converted 4292 detections to points -> results/rfdetr_nano/rfdetr_stage1_detections_points.csv
#                                          images            x            y  \
# 0  01802f75da35434ab373569fffc1fd65a3417aef.JPG  1472.237793   262.071701
# 1  01802f75da35434ab373569fffc1fd65a3417aef.JPG  4673.474609   251.195457
# 2  01802f75da35434ab373569fffc1fd65a3417aef.JPG  2985.883301   906.458740
# 3  01802f75da35434ab373569fffc1fd65a3417aef.JPG  5190.343262  1105.431396
# 4  01802f75da35434ab373569fffc1fd65a3417aef.JPG  1168.424866  1482.091553
#
#    labels    scores
# 0       6  0.513108
# 1       6  0.667662
# 2       6  0.581643
# 3       6  0.693571
# 4       6  0.745156

# %% [markdown]
# #### Calcular métricas HerdNet

# %%
metrics_summary = evaluate_points_from_csv(
    gt_csv=eval_cfg.data.gt_points_csv,
    detections_csv=points_path,
    class_map_path=eval_cfg.metrics.class_map,
    radius=eval_cfg.metrics.radius,
)
metrics_summary['overall']

# %% [markdown]
# ## Fase 2 — Hard Negatives y Stage 2
#
# Usamos el modelo de la fase 1 para recolectar falsos positivos, generar parches negativos y reentrenar RF-DETR con el dataset ampliado (dataset de la fase 1 + parches negativos).

# %% [markdown]
# ### Inferencia sobre el split de entrenamiento
# Se realiza la inferencia sobre las imágenes originales (24MP) del conjunto de entrenamiento

# %%
hn_cfg = OmegaConf.create({
    'data': {
        'train_root': 'data-delplanque/train',
    },
    'inference': {
        'device': 'cuda',
        'checkpoint_path': './outputs/rfdetr_large/checkpoint_best_total.pth',
        'threshold': 0.5,
        'batch_size': 16,
        'output_path': './results/rfdetr_large',
        'detections_csv': 'rfdetr_large_stage1_train_detections.csv',
        'detections_json': 'rfdetr_large_stage1_train_detections.json',
    },
    'patches': {
        'patch_width': PATCH_SIZE,
        'patch_height': PATCH_SIZE,
        'overlap': 160,
        'min_visibility': 0.8,
        'output_dir': 'data-large-detr/hnp',
    },
})

# %%
hn_checkpoint = torch.load(hn_cfg.inference.checkpoint_path, weights_only=False)
hn_state = hn_checkpoint.get('model', hn_checkpoint.get('ema_model'))
hn_num_classes = hn_state['class_embed.weight'].shape[0]

hn_model = RFDETRLarge()
hn_model.model.reinitialize_detection_head(hn_num_classes)
hn_model.model.model.load_state_dict(hn_state, strict=True)
hn_model.model.model.to(hn_cfg.inference.device).eval()

hn_stitcher = SimpleStitcher(
    model=hn_model.model.model,
    patch_size=hn_cfg.patches.patch_width,
    overlap=0,
    batch_size=hn_cfg.inference.batch_size,
    confidence_threshold=hn_cfg.inference.threshold,
    device=hn_cfg.inference.device,
    label_offset=0,
)
# Out:
# Loading pretrain weights

# %%
train_root = Path(hn_cfg.data.train_root)
train_images = sorted(
    list(train_root.glob('*.jpg')) +
    list(train_root.glob('*.JPG')) +
    list(train_root.glob('*.png')) +
    list(train_root.glob('*.PNG'))
)

transform = A.Compose([
    A.Normalize(mean=IMG_NORMALIZE_MEAN, std=IMG_NORMALIZE_STD),
    ToTensorV2(),
])

hn_output_dir = Path(hn_cfg.inference.output_path)
hn_output_dir.mkdir(parents=True, exist_ok=True)
hn_records = []
hn_samples = []

for img_path in tqdm(train_images, desc='HN inference'):
    image = Image.open(img_path).convert('RGB')
    width, height = image.size
    tensor = transform(image=np.array(image))['image']
    detections = hn_stitcher(tensor)

    det_list = []
    for i in range(len(detections['scores'])):
        x1, y1, x2, y2 = detections['boxes'][i].tolist()
        label = int(detections['labels'][i])
        score = float(detections['scores'][i])
        hn_records.append({
            'images': img_path.name,
            'x': x1,
            'y': y1,
            'x_max': x2,
            'y_max': y2,
            'labels': label,
            'scores': score,
        })
        det_list.append(Detection(bbox=[x1, y1, x2, y2], label=label, score=score))

    hn_samples.append(DetectionSample(file_name=img_path.name, width=width, height=height, detections=det_list))

hn_df = pd.DataFrame(hn_records)
hn_csv_path = hn_output_dir / hn_cfg.inference.detections_csv
hn_df.to_csv(hn_csv_path, index=False)
write_coco_predictions(hn_samples, hn_output_dir / hn_cfg.inference.detections_json)
hn_csv_path
# Out:
# HN inference:  43%|████▎     | 395/928 [06:30<09:41,  1.09s/it]

# %% [markdown]
# ### Generar parches negativos
#
# Utilizamos el JSON de detecciones para identificar los parches que contienen falsos positivos y se estructura el dataset para que en la carpeta *train/* se tenga el conjunto de datos de train de la fase 1 y los falsos positivos generados.
#
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)

# %%
# Preparar directorios para Stage 2
stage2_train_dir = Path("data-large-detr-stage2/train")
stage2_train_dir.mkdir(parents=True, exist_ok=True)

# Copiar imágenes originales de Stage 1
print("Copying original Stage 1 patches...")
original_patches_dir = Path("data-large-detr/train")
for pattern in ("*.jpg", "*.JPG"):
    for src in original_patches_dir.glob(pattern):
        dst = stage2_train_dir / src.name
        if not dst.exists():
            copy2(src, dst)

# Cargar el JSON original de Stage 1
original_json = Path("data-large-detr/train/_annotations.coco.json")
original_coco = json.loads(original_json.read_text())
original_filenames = {img["file_name"] for img in original_coco["images"]}

print(f"\nStage 1 dataset: {len(original_coco['images'])} images, {len(original_coco['annotations'])} annotations")

# Generar patches con el patcher (incluye TPs y FPs)
print("\nGenerating patches from model predictions...")

hnp_summary = generate_patch_dataset(
    images_dir=hn_cfg.data.train_root,
    json_file=hn_output_dir / hn_cfg.inference.detections_json,
    output_dir=stage2_train_dir,
    patch_width=hn_cfg.patches.patch_width,
    patch_height=hn_cfg.patches.patch_height,
    overlap=hn_cfg.patches.overlap,
    min_visibility=hn_cfg.patches.min_visibility,
)

# Leer el JSON generado por el patcher
hnp_json_path = stage2_train_dir / "_annotations.coco.json"
hnp_coco = json.loads(hnp_json_path.read_text())

# Filtrar: Solo patches NUEVOS (que no están en Stage 1) son HNP
print("\nFiltering Hard Negative Patches (FPs)...")
new_hnp_images = [img for img in hnp_coco["images"] if img["file_name"] not in original_filenames]

print(f"  Total patches generated: {len(hnp_coco['images'])}")
print(f"  Patches matching Stage 1 (TPs, skipped): {len(hnp_coco['images']) - len(new_hnp_images)}")
print(f"  New Hard Negative Patches (FPs): {len(new_hnp_images)}")

# Combinar: Stage 1 (con anotaciones) + HNP (sin anotaciones)
print("\nMerging Stage 1 + HNP...")
next_image_id = max((img["id"] for img in original_coco["images"]), default=0) + 1

stage2_coco = {
    "info": original_coco.get("info", {}),
    "licenses": original_coco.get("licenses", []),
    "categories": original_coco.get("categories", []),
    "images": list(original_coco["images"]),
    "annotations": list(original_coco["annotations"]),  # Solo anotaciones de Stage 1
}

# Agregar imágenes HNP (sin anotaciones - son fondos puros)
for hnp_img in new_hnp_images:
    stage2_coco["images"].append({
        **hnp_img,
        "id": next_image_id,
    })
    next_image_id += 1

# Guardar JSON final de Stage 2
hnp_json_path.write_text(json.dumps(stage2_coco, indent=2))

print(f"\n✓ Stage 2 dataset ready:")
print(f"  - Images: {len(stage2_coco['images'])} (Stage 1: {len(original_coco['images'])}, HNP: {len(new_hnp_images)})")
print(f"  - Annotations: {len(stage2_coco['annotations'])} (only from Stage 1, HNP have no annotations)")
print(f"  - Location: {stage2_train_dir}")

pd.DataFrame([{
    "stage1_images": len(original_coco['images']),
    "hnp_images": len(new_hnp_images),
    "total_images": len(stage2_coco['images']),
    "stage1_anns": len(original_coco['annotations']),
    "hnp_anns": 0,
    "total_anns": len(stage2_coco['annotations']),
}])
# Out:
# Patching images: 100%|██████████| 928/928 [12:29<00:00,  1.24it/s]
# Filtering Hard Negative Patches (FPs)...
#   Total patches generated: 12991
#   Patches matching Stage 1 (TPs, skipped): 6803
#   New Hard Negative Patches (FPs): 6188
#
# Merging Stage 1 + HNP...
#
# ✓ Stage 2 dataset ready:
#   - Images: 14241 (Stage 1: 8053, HNP: 6188)
#   - Annotations: 15893 (only from Stage 1, HNP have no annotations)
#   - Location: data-large-detr-stage2/train
#    stage1_images  hnp_images  total_images  stage1_anns  hnp_anns  total_anns
# 0           8053        6188         14241        15893         0       15893

# %% [markdown]
# El dataset de validación es el mismo de la fase 1

# %%
# Preparar validación para Stage 2 (reutilizar la misma de Stage 1)
stage2_valid_dir = Path("data-large-detr-stage2/valid")
if not stage2_valid_dir.exists():
    print("Creating validation dataset for Stage 2...")
    stage2_valid_dir.mkdir(parents=True, exist_ok=True)
    
    # Copiar imágenes de validación
    stage1_valid = Path("data-large-detr/valid")
    for pattern in ("*.jpg", "*.JPG"):
        for src in stage1_valid.glob(pattern):
            copy2(src, stage2_valid_dir / src.name)
    
    # Copiar JSON de validación
    copy2(stage1_valid / "_annotations.coco.json", stage2_valid_dir / "_annotations.coco.json")
    print(f"✓ Validation dataset ready: {stage2_valid_dir}")
else:
    print(f"✓ Validation dataset already exists: {stage2_valid_dir}")
# Out:
# Creating validation dataset for Stage 2...
# ✓ Validation dataset ready: data-large-detr-stage2/valid

# %% [markdown]
# ### Entrenamiento

# %%
checkpoint_stage1 = torch.load(hn_cfg.inference.checkpoint_path, weights_only=False)
state_dict_stage1 = checkpoint_stage1.get('model', checkpoint_stage1.get('ema_model'))
num_classes_stage1 = state_dict_stage1['class_embed.weight'].shape[0]

print(f"🔄 Loading Stage 1 checkpoint: num_classes={num_classes_stage1}")

# Crear modelo y cargar pesos MANUALMENTE
model_stage2 = RFDETRLarge()
model_stage2.model.reinitialize_detection_head(num_classes_stage1)
model_stage2.model.model.load_state_dict(state_dict_stage1, strict=True)

print(f"✅ Stage 1 weights loaded successfully!")

herdnet_callback_stage2 = HerdNetMetricsCallback(
    model=model_stage2,
    val_dataset_path='data-large-detr-stage2/valid/_annotations.coco.json',
    val_images_dir='data-large-detr-stage2/valid',
    threshold_px=20,
    confidence_threshold=0.5,
    wandb_log=True,
    eval_every_n_epochs=5,
)

model_stage2.callbacks['on_fit_epoch_end'].append(herdnet_callback_stage2.update)
# Out:
# 🔄 Loading Stage 1 checkpoint: num_classes=7
# Loading pretrain weights
# ✅ Stage 1 weights loaded successfully!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!

# %%
model_stage2.train(
    dataset_dir='data-large-detr-stage2',
    dataset_file='roboflow',
    img_size=PATCH_SIZE,
    epochs=50,
    batch_size=2, 
    grad_accum_steps=8,
    lr=1e-5,
    lr_encoder=1e-5, 
    ema_decay=0.993,
    weight_decay=1e-4,
    multi_scale=True,
    output_dir='outputs/rfdetr_large_stage2',
    wandb=True,
    project='rf-detr-large',
)
# Out:
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir outputs/rfdetr_large_stage2' and open http://localhost:6006/ in browser.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>outputs/rfdetr_large_stage2/wandb/run-20251112_021052-k9rjh4n7</code>
# Syncing run <strong><a href='https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large/runs/k9rjh4n7' target="_blank">misty-glade-9</a></strong> to <a href='https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large' target="_blank">https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large</a>
#  View run at <a href='https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large/runs/k9rjh4n7' target="_blank">https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large/runs/k9rjh4n7</a>
# W&B logging initialized. To monitor logs, open https://wandb.ai/luis-manrique-car-camera-traps/rf-detr-large/runs/k9rjh4n7.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=7, grad_accum_steps=8, amp=True, lr=1e-05, lr_encoder=1e-05, batch_size=2, weight_decay=0.0001, epochs=50, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-large.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_base', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=384, sa_nheads=12, ca_nheads=24, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P3', 'P5'], lite_refpoint_refine=True, num_select=300, dec_n_points=4, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='data-large-detr-stage2', square_resize_div_64=True, output_dir='outputs/rfdetr_large_stage2', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=560, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=14, num_windows=4, positional_encoding_size=37, mask_downsample_ratio=4, tensorboard=True, wandb=True, project='rf-detr-large', run=None, class_names=['Alcelaphinae', 'Buffalo', 'Kob', 'Warthog', 'Waterbuck', 'Elephant'], run_test=True, segmentation_head=False, img_size=560, distributed=False)
# number of params: 135184714
# [840]
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# [840]
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# [840]
# loading annotations into memory...
# fatal: not a git repository (or any of the parent directories): .git
# Done (t=0.03s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  8
# Total batch size:  16
# LENGTH OF DATA LOADER: 890
# Epoch: [0]  [  0/890]  eta: 0:30:28  lr: 0.000010  class_error: 0.00  loss: 4.2570 (4.2570)  loss_ce: 0.4956 (0.4956)  loss_bbox: 0.1606 (0.1606)  loss_giou: 0.3419 (0.3419)  loss_ce_0: 0.5061 (0.5061)  loss_bbox_0: 0.1533 (0.1533)  loss_giou_0: 0.3346 (0.3346)  loss_ce_1: 0.5136 (0.5136)  loss_bbox_1: 0.1595 (0.1595)  loss_giou_1: 0.3429 (0.3429)  loss_ce_enc: 0.6106 (0.6106)  loss_bbox_enc: 0.2000 (0.2000)  loss_giou_enc: 0.4383 (0.4383)  loss_ce_unscaled: 0.4956 (0.4956)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0321 (0.0321)  loss_giou_unscaled: 0.1710 (0.1710)  cardinality_error_unscaled: 1949.5000 (1949.5000)  loss_ce_0_unscaled: 0.5061 (0.5061)  loss_bbox_0_unscaled: 0.0307 (0.0307)  loss_giou_0_unscaled: 0.1673 (0.1673)  cardinality_error_0_unscaled: 1955.5000 (1955.5000)  loss_ce_1_unscaled: 0.5136 (0.5136)  loss_bbox_1_unscaled: 0.0319 (0.0319)  loss_giou_1_unscaled: 0.1715 (0.1715)  cardinality_error_1_unscaled: 1949.5000 (1949.5000)  loss_ce_enc_unscaled: 0.6106 (0.6106)  loss_bbox_enc_unscaled: 0.0400 (0.0400)  loss_giou_enc_unscaled: 0.2192 (0.2192)  cardinality_error_enc_unscaled: 1956.0000 (1956.0000)  time: 2.0543  data: 1.1123  max mem: 13413
# Epoch: [0]  [ 10/890]  eta: 0:13:50  lr: 0.000010  class_error: 0.00  loss: 3.5078 (4.8911)  loss_ce: 0.4956 (0.9895)  loss_bbox: 0.0409 (0.0545)  loss_giou: 0.2896 (0.2065)  loss_ce_0: 0.5061 (0.7793)  loss_bbox_0: 0.0451 (0.0543)  loss_giou_0: 0.2964 (0.2070)  loss_ce_1: 0.5136 (1.0254)  loss_bbox_1: 0.0481 (0.0553)  loss_giou_1: 0.2896 (0.2096)  loss_ce_enc: 0.4729 (1.0301)  loss_bbox_enc: 0.0349 (0.0585)  loss_giou_enc: 0.2959 (0.2210)  loss_ce_unscaled: 0.4956 (0.9895)  class_error_unscaled: 0.0000 (45.4545)  loss_bbox_unscaled: 0.0082 (0.0109)  loss_giou_unscaled: 0.1448 (0.1033)  cardinality_error_unscaled: 3778.0000 (3128.5909)  loss_ce_0_unscaled: 0.5061 (0.7793)  loss_bbox_0_unscaled: 0.0090 (0.0109)  loss_giou_0_unscaled: 0.1482 (0.1035)  cardinality_error_0_unscaled: 3841.0000 (3175.3636)  loss_ce_1_unscaled: 0.5136 (1.0254)  loss_bbox_1_unscaled: 0.0096 (0.0111)  loss_giou_1_unscaled: 0.1448 (0.1048)  cardinality_error_1_unscaled: 3798.0000 (3171.0455)  loss_ce_enc_unscaled: 0.4729 (1.0301)  loss_bbox_enc_unscaled: 0.0070 (0.0117)  loss_giou_enc_unscaled: 0.1480 (0.1105)  cardinality_error_enc_unscaled: 3724.0000 (3180.3636)  time: 0.9434  data: 0.1194  max mem: 13413
# Epoch: [0]  [ 20/890]  eta: 0:13:00  lr: 0.000010  class_error: 0.00  loss: 3.5078 (5.6360)  loss_ce: 0.4980 (1.1563)  loss_bbox: 0.0710 (0.0630)  loss_giou: 0.2970 (0.2429)  loss_ce_0: 0.4919 (1.0342)  loss_bbox_0: 0.0662 (0.0660)  loss_giou_0: 0.2964 (0.2482)  loss_ce_1: 0.4950 (1.2301)  loss_bbox_1: 0.0698 (0.0638)  loss_giou_1: 0.3054 (0.2457)  loss_ce_enc: 0.5142 (0.9527)  loss_bbox_enc: 0.0767 (0.0699)  loss_giou_enc: 0.3038 (0.2632)  loss_ce_unscaled: 0.4980 (1.1563)  class_error_unscaled: 0.0000 (33.4554)  loss_bbox_unscaled: 0.0142 (0.0126)  loss_giou_unscaled: 0.1485 (0.1215)  cardinality_error_unscaled: 3839.0000 (3034.6905)  loss_ce_0_unscaled: 0.4919 (1.0342)  loss_bbox_0_unscaled: 0.0132 (0.0132)  loss_giou_0_unscaled: 0.1482 (0.1241)  cardinality_error_0_unscaled: 3862.5000 (3103.1905)  loss_ce_1_unscaled: 0.4950 (1.2301)  loss_bbox_1_unscaled: 0.0140 (0.0128)  loss_giou_1_unscaled: 0.1527 (0.1228)  cardinality_error_1_unscaled: 3880.0000 (3083.2857)  loss_ce_enc_unscaled: 0.5142 (0.9527)  loss_bbox_enc_unscaled: 0.0153 (0.0140)  loss_giou_enc_unscaled: 0.1519 (0.1316)  cardinality_error_enc_unscaled: 3864.0000 (3130.5000)  time: 0.8389  data: 0.0179  max mem: 13413
# Epoch: [0]  [ 30/890]  eta: 0:12:24  lr: 0.000010  class_error: 0.00  loss: 3.6345 (4.8169)  loss_ce: 0.4741 (0.9316)  loss_bbox: 0.0712 (0.0641)  loss_giou: 0.3045 (0.2377)  loss_ce_0: 0.4743 (0.8451)  loss_bbox_0: 0.0683 (0.0653)  loss_giou_0: 0.2963 (0.2396)  loss_ce_1: 0.4760 (0.9796)  loss_bbox_1: 0.0717 (0.0654)  loss_giou_1: 0.3104 (0.2413)  loss_ce_enc: 0.5160 (0.8150)  loss_bbox_enc: 0.0908 (0.0708)  loss_giou_enc: 0.3227 (0.2614)  loss_ce_unscaled: 0.4741 (0.9316)  class_error_unscaled: 0.0000 (32.3408)  loss_bbox_unscaled: 0.0142 (0.0128)  loss_giou_unscaled: 0.1522 (0.1188)  cardinality_error_unscaled: 2052.0000 (2812.6774)  loss_ce_0_unscaled: 0.4743 (0.8451)  loss_bbox_0_unscaled: 0.0137 (0.0131)  loss_giou_0_unscaled: 0.1482 (0.1198)  cardinality_error_0_unscaled: 2317.0000 (2890.5806)  loss_ce_1_unscaled: 0.4760 (0.9796)  loss_bbox_1_unscaled: 0.0143 (0.0131)  loss_giou_1_unscaled: 0.1552 (0.1207)  cardinality_error_1_unscaled: 2374.5000 (2891.4839)  loss_ce_enc_unscaled: 0.5160 (0.8150)  loss_bbox_enc_unscaled: 0.0182 (0.0142)  loss_giou_enc_unscaled: 0.1614 (0.1307)  cardinality_error_enc_unscaled: 2437.0000 (2930.1935)  time: 0.8235  data: 0.0154  max mem: 13413
# Epoch: [0]  [ 40/890]  eta: 0:12:13  lr: 0.000010  class_error: 0.00  loss: 3.6345 (4.5570)  loss_ce: 0.4602 (0.8643)  loss_bbox: 0.0553 (0.0652)  loss_giou: 0.2251 (0.2393)  loss_ce_0: 0.4990 (0.7922)  loss_bbox_0: 0.0571 (0.0663)  loss_giou_0: 0.2264 (0.2396)  loss_ce_1: 0.4609 (0.9025)  loss_bbox_1: 0.0559 (0.0656)  loss_giou_1: 0.2318 (0.2398)  loss_ce_enc: 0.5584 (0.7485)  loss_bbox_enc: 0.0604 (0.0716)  loss_giou_enc: 0.2564 (0.2620)  loss_ce_unscaled: 0.4602 (0.8643)  class_error_unscaled: 0.0000 (34.2089)  loss_bbox_unscaled: 0.0111 (0.0130)  loss_giou_unscaled: 0.1126 (0.1197)  cardinality_error_unscaled: 2095.5000 (2888.1951)  loss_ce_0_unscaled: 0.4990 (0.7922)  loss_bbox_0_unscaled: 0.0114 (0.0133)  loss_giou_0_unscaled: 0.1132 (0.1198)  cardinality_error_0_unscaled: 2689.5000 (2970.2927)  loss_ce_1_unscaled: 0.4609 (0.9025)  loss_bbox_1_unscaled: 0.0112 (0.0131)  loss_giou_1_unscaled: 0.1159 (0.1199)  cardinality_error_1_unscaled: 2575.5000 (2974.5488)  loss_ce_enc_unscaled: 0.5584 (0.7485)  loss_bbox_enc_unscaled: 0.0121 (0.0143)  loss_giou_enc_unscaled: 0.1282 (0.1310)  cardinality_error_enc_unscaled: 2581.0000 (3008.0732)  time: 0.8274  data: 0.0147  max mem: 13413
# Epoch: [0]  [ 50/890]  eta: 0:11:55  lr: 0.000010  class_error: 0.00  loss: 3.1031 (4.3664)  loss_ce: 0.4813 (0.7835)  loss_bbox: 0.0595 (0.0704)  loss_giou: 0.1987 (0.2558)  loss_ce_0: 0.5078 (0.7294)  loss_bbox_0: 0.0589 (0.0717)  loss_giou_0: 0.2037 (0.2568)  loss_ce_1: 0.4974 (0.8157)  loss_bbox_1: 0.0598 (0.0709)  loss_giou_1: 0.2006 (0.2561)  loss_ce_enc: 0.5584 (0.7011)  loss_bbox_enc: 0.0602 (0.0770)  loss_giou_enc: 0.2510 (0.2781)  loss_ce_unscaled: 0.4813 (0.7835)  class_error_unscaled: 0.0000 (29.4620)  loss_bbox_unscaled: 0.0119 (0.0141)  loss_giou_unscaled: 0.0994 (0.1279)  cardinality_error_unscaled: 3843.0000 (2939.6765)  loss_ce_0_unscaled: 0.5078 (0.7294)  loss_bbox_0_unscaled: 0.0118 (0.0143)  loss_giou_0_unscaled: 0.1019 (0.1284)  cardinality_error_0_unscaled: 3883.5000 (3025.3529)  loss_ce_1_unscaled: 0.4974 (0.8157)  loss_bbox_1_unscaled: 0.0120 (0.0142)  loss_giou_1_unscaled: 0.1003 (0.1280)  cardinality_error_1_unscaled: 3894.5000 (3034.9412)  loss_ce_enc_unscaled: 0.5584 (0.7011)  loss_bbox_enc_unscaled: 0.0120 (0.0154)  loss_giou_enc_unscaled: 0.1255 (0.1390)  cardinality_error_enc_unscaled: 3894.5000 (3064.2549)  time: 0.8300  data: 0.0149  max mem: 13413
# Epoch: [0]  [ 60/890]  eta: 0:11:41  lr: 0.000010  class_error: 0.00  loss: 4.0854 (4.3576)  loss_ce: 0.4980 (0.7584)  loss_bbox: 0.0608 (0.0725)  loss_giou: 0.2768 (0.2720)  loss_ce_0: 0.5214 (0.7152)  loss_bbox_0: 0.0726 (0.0731)  loss_giou_0: 0.2761 (0.2726)  loss_ce_1: 0.4974 (0.7834)  loss_bbox_1: 0.0694 (0.0729)  loss_giou_1: 0.2805 (0.2729)  loss_ce_enc: 0.5588 (0.6919)  loss_bbox_enc: 0.0794 (0.0783)  loss_giou_enc: 0.3197 (0.2946)  loss_ce_unscaled: 0.4980 (0.7584)  class_error_unscaled: 0.0000 (24.6322)  loss_bbox_unscaled: 0.0122 (0.0145)  loss_giou_unscaled: 0.1384 (0.1360)  cardinality_error_unscaled: 2894.5000 (2957.4836)  loss_ce_0_unscaled: 0.5214 (0.7152)  loss_bbox_0_unscaled: 0.0145 (0.0146)  loss_giou_0_unscaled: 0.1381 (0.1363)  cardinality_error_0_unscaled: 3128.0000 (3047.6148)  loss_ce_1_unscaled: 0.4974 (0.7834)  loss_bbox_1_unscaled: 0.0139 (0.0146)  loss_giou_1_unscaled: 0.1402 (0.1365)  cardinality_error_1_unscaled: 3301.0000 (3059.8770)  loss_ce_enc_unscaled: 0.5588 (0.6919)  loss_bbox_enc_unscaled: 0.0159 (0.0157)  loss_giou_enc_unscaled: 0.1598 (0.1473)  cardinality_error_enc_unscaled: 3387.0000 (3092.7295)  time: 0.8081  data: 0.0182  max mem: 13413
# Epoch: [0]  [ 70/890]  eta: 0:11:30  lr: 0.000010  class_error: 0.00  loss: 3.3758 (4.1053)  loss_ce: 0.4885 (0.7015)  loss_bbox: 0.0606 (0.0693)  loss_giou: 0.2439 (0.2618)  loss_ce_0: 0.5011 (0.6680)  loss_bbox_0: 0.0726 (0.0698)  loss_giou_0: 0.2579 (0.2627)  loss_ce_1: 0.4670 (0.7231)  loss_bbox_1: 0.0694 (0.0695)  loss_giou_1: 0.2451 (0.2630)  loss_ce_enc: 0.4955 (0.6569)  loss_bbox_enc: 0.0697 (0.0760)  loss_giou_enc: 0.3047 (0.2835)  loss_ce_unscaled: 0.4885 (0.7015)  class_error_unscaled: 0.0000 (26.7967)  loss_bbox_unscaled: 0.0121 (0.0139)  loss_giou_unscaled: 0.1219 (0.1309)  cardinality_error_unscaled: 2099.0000 (2887.0986)  loss_ce_0_unscaled: 0.5011 (0.6680)  loss_bbox_0_unscaled: 0.0145 (0.0140)  loss_giou_0_unscaled: 0.1290 (0.1314)  cardinality_error_0_unscaled: 2420.5000 (2990.4930)  loss_ce_1_unscaled: 0.4670 (0.7231)  loss_bbox_1_unscaled: 0.0139 (0.0139)  loss_giou_1_unscaled: 0.1226 (0.1315)  cardinality_error_1_unscaled: 2603.0000 (3005.1620)  loss_ce_enc_unscaled: 0.4955 (0.6569)  loss_bbox_enc_unscaled: 0.0139 (0.0152)  loss_giou_enc_unscaled: 0.1524 (0.1418)  cardinality_error_enc_unscaled: 2609.0000 (3027.4225)  time: 0.8169  data: 0.0181  max mem: 13413
# Epoch: [0]  [ 80/890]  eta: 0:11:16  lr: 0.000010  class_error: 0.00  loss: 3.3060 (3.9864)  loss_ce: 0.4376 (0.6653)  loss_bbox: 0.0465 (0.0703)  loss_giou: 0.2439 (0.2645)  loss_ce_0: 0.4784 (0.6381)  loss_bbox_0: 0.0454 (0.0708)  loss_giou_0: 0.2579 (0.2652)  loss_ce_1: 0.4404 (0.6844)  loss_bbox_1: 0.0466 (0.0705)  loss_giou_1: 0.2451 (0.2656)  loss_ce_enc: 0.4416 (0.6275)  loss_bbox_enc: 0.0675 (0.0769)  loss_giou_enc: 0.3330 (0.2872)  loss_ce_unscaled: 0.4376 (0.6653)  class_error_unscaled: 0.0000 (25.9576)  loss_bbox_unscaled: 0.0093 (0.0141)  loss_giou_unscaled: 0.1219 (0.1322)  cardinality_error_unscaled: 2104.5000 (2879.4691)  loss_ce_0_unscaled: 0.4784 (0.6381)  loss_bbox_0_unscaled: 0.0091 (0.0142)  loss_giou_0_unscaled: 0.1290 (0.1326)  cardinality_error_0_unscaled: 2345.0000 (2975.2963)  loss_ce_1_unscaled: 0.4404 (0.6844)  loss_bbox_1_unscaled: 0.0093 (0.0141)  loss_giou_1_unscaled: 0.1226 (0.1328)  cardinality_error_1_unscaled: 2482.0000 (2991.6358)  loss_ce_enc_unscaled: 0.4416 (0.6275)  loss_bbox_enc_unscaled: 0.0135 (0.0154)  loss_giou_enc_unscaled: 0.1665 (0.1436)  cardinality_error_enc_unscaled: 2347.5000 (3011.7901)  time: 0.8066  data: 0.0152  max mem: 13413
# Epoch: [0]  [ 90/890]  eta: 0:11:01  lr: 0.000010  class_error: 0.00  loss: 3.6653 (4.2068)  loss_ce: 0.4546 (0.7519)  loss_bbox: 0.0577 (0.0671)  loss_giou: 0.2581 (0.2563)  loss_ce_0: 0.5088 (0.6935)  loss_bbox_0: 0.0604 (0.0677)  loss_giou_0: 0.2772 (0.2571)  loss_ce_1: 0.4532 (0.7494)  loss_bbox_1: 0.0586 (0.0674)  loss_giou_1: 0.2746 (0.2575)  loss_ce_enc: 0.4783 (0.6886)  loss_bbox_enc: 0.0609 (0.0730)  loss_giou_enc: 0.3330 (0.2773)  loss_ce_unscaled: 0.4546 (0.7519)  class_error_unscaled: 0.0000 (27.5007)  loss_bbox_unscaled: 0.0115 (0.0134)  loss_giou_unscaled: 0.1291 (0.1281)  cardinality_error_unscaled: 2272.0000 (2859.9505)  loss_ce_0_unscaled: 0.5088 (0.6935)  loss_bbox_0_unscaled: 0.0121 (0.0135)  loss_giou_0_unscaled: 0.1386 (0.1286)  cardinality_error_0_unscaled: 2543.0000 (2956.0000)  loss_ce_1_unscaled: 0.4532 (0.7494)  loss_bbox_1_unscaled: 0.0117 (0.0135)  loss_giou_1_unscaled: 0.1373 (0.1288)  cardinality_error_1_unscaled: 2823.0000 (2984.0549)  loss_ce_enc_unscaled: 0.4783 (0.6886)  loss_bbox_enc_unscaled: 0.0122 (0.0146)  loss_giou_enc_unscaled: 0.1665 (0.1387)  cardinality_error_enc_unscaled: 2616.0000 (2996.7473)  time: 0.7757  data: 0.0150  max mem: 13413
# Epoch: [0]  [100/890]  eta: 0:10:51  lr: 0.000010  class_error: 0.00  loss: 3.7968 (4.1690)  loss_ce: 0.4983 (0.7275)  loss_bbox: 0.0600 (0.0688)  loss_giou: 0.3052 (0.2654)  loss_ce_0: 0.5082 (0.6764)  loss_bbox_0: 0.0613 (0.0694)  loss_giou_0: 0.3049 (0.2669)  loss_ce_1: 0.4932 (0.7255)  loss_bbox_1: 0.0608 (0.0692)  loss_giou_1: 0.3040 (0.2671)  loss_ce_enc: 0.5089 (0.6729)  loss_bbox_enc: 0.0609 (0.0739)  loss_giou_enc: 0.2953 (0.2860)  loss_ce_unscaled: 0.4983 (0.7275)  class_error_unscaled: 0.0000 (25.7680)  loss_bbox_unscaled: 0.0120 (0.0138)  loss_giou_unscaled: 0.1526 (0.1327)  cardinality_error_unscaled: 2059.5000 (2833.1436)  loss_ce_0_unscaled: 0.5082 (0.6764)  loss_bbox_0_unscaled: 0.0123 (0.0139)  loss_giou_0_unscaled: 0.1524 (0.1334)  cardinality_error_0_unscaled: 2244.5000 (2928.0545)  loss_ce_1_unscaled: 0.4932 (0.7255)  loss_bbox_1_unscaled: 0.0122 (0.0138)  loss_giou_1_unscaled: 0.1520 (0.1335)  cardinality_error_1_unscaled: 2325.5000 (2956.9307)  loss_ce_enc_unscaled: 0.5089 (0.6729)  loss_bbox_enc_unscaled: 0.0122 (0.0148)  loss_giou_enc_unscaled: 0.1476 (0.1430)  cardinality_error_enc_unscaled: 2304.5000 (2966.6584)  time: 0.7831  data: 0.0153  max mem: 13413
# Epoch: [0]  [110/890]  eta: 0:10:41  lr: 0.000010  class_error: 0.00  loss: 3.3801 (4.0213)  loss_ce: 0.4385 (0.6896)  loss_bbox: 0.0648 (0.0676)  loss_giou: 0.2995 (0.2652)  loss_ce_0: 0.4370 (0.6461)  loss_bbox_0: 0.0656 (0.0672)  loss_giou_0: 0.3027 (0.2641)  loss_ce_1: 0.4311 (0.6875)  loss_bbox_1: 0.0653 (0.0683)  loss_giou_1: 0.3029 (0.2673)  loss_ce_enc: 0.4600 (0.6435)  loss_bbox_enc: 0.0647 (0.0720)  loss_giou_enc: 0.2953 (0.2827)  loss_ce_unscaled: 0.4385 (0.6896)  class_error_unscaled: 0.0000 (27.0501)  loss_bbox_unscaled: 0.0130 (0.0135)  loss_giou_unscaled: 0.1497 (0.1326)  cardinality_error_unscaled: 2160.5000 (2783.8514)  loss_ce_0_unscaled: 0.4370 (0.6461)  loss_bbox_0_unscaled: 0.0131 (0.0134)  loss_giou_0_unscaled: 0.1513 (0.1320)  cardinality_error_0_unscaled: 2202.0000 (2885.3198)  loss_ce_1_unscaled: 0.4311 (0.6875)  loss_bbox_1_unscaled: 0.0131 (0.0137)  loss_giou_1_unscaled: 0.1514 (0.1337)  cardinality_error_1_unscaled: 2318.0000 (2921.5000)  loss_ce_enc_unscaled: 0.4600 (0.6435)  loss_bbox_enc_unscaled: 0.0129 (0.0144)  loss_giou_enc_unscaled: 0.1476 (0.1413)  cardinality_error_enc_unscaled: 2304.5000 (2931.2523)  time: 0.7978  data: 0.0172  max mem: 13413
# Epoch: [0]  [120/890]  eta: 0:10:32  lr: 0.000010  class_error: 100.00  loss: 2.6287 (3.9786)  loss_ce: 0.4059 (0.6729)  loss_bbox: 0.0519 (0.0674)  loss_giou: 0.2232 (0.2683)  loss_ce_0: 0.4215 (0.6341)  loss_bbox_0: 0.0502 (0.0673)  loss_giou_0: 0.2364 (0.2679)  loss_ce_1: 0.3995 (0.6712)  loss_bbox_1: 0.0515 (0.0682)  loss_giou_1: 0.2283 (0.2703)  loss_ce_enc: 0.4277 (0.6317)  loss_bbox_enc: 0.0556 (0.0724)  loss_giou_enc: 0.2375 (0.2870)  loss_ce_unscaled: 0.4059 (0.6729)  class_error_unscaled: 0.0000 (26.4675)  loss_bbox_unscaled: 0.0104 (0.0135)  loss_giou_unscaled: 0.1116 (0.1341)  cardinality_error_unscaled: 2167.5000 (2796.5909)  loss_ce_0_unscaled: 0.4215 (0.6341)  loss_bbox_0_unscaled: 0.0100 (0.0135)  loss_giou_0_unscaled: 0.1182 (0.1339)  cardinality_error_0_unscaled: 2250.0000 (2888.7149)  loss_ce_1_unscaled: 0.3995 (0.6712)  loss_bbox_1_unscaled: 0.0103 (0.0136)  loss_giou_1_unscaled: 0.1142 (0.1351)  cardinality_error_1_unscaled: 2407.0000 (2926.7438)  loss_ce_enc_unscaled: 0.4277 (0.6317)  loss_bbox_enc_unscaled: 0.0111 (0.0145)  loss_giou_enc_unscaled: 0.1188 (0.1435)  cardinality_error_enc_unscaled: 2391.0000 (2933.0289)  time: 0.8016  data: 0.0184  max mem: 13413
# Epoch: [0]  [130/890]  eta: 0:10:22  lr: 0.000010  class_error: 100.00  loss: 3.0362 (3.9284)  loss_ce: 0.4284 (0.6592)  loss_bbox: 0.0623 (0.0663)  loss_giou: 0.2360 (0.2674)  loss_ce_0: 0.4831 (0.6254)  loss_bbox_0: 0.0636 (0.0663)  loss_giou_0: 0.2458 (0.2675)  loss_ce_1: 0.4373 (0.6570)  loss_bbox_1: 0.0637 (0.0670)  loss_giou_1: 0.2347 (0.2693)  loss_ce_enc: 0.4848 (0.6252)  loss_bbox_enc: 0.0598 (0.0710)  loss_giou_enc: 0.2618 (0.2870)  loss_ce_unscaled: 0.4284 (0.6592)  class_error_unscaled: 0.0000 (25.9738)  loss_bbox_unscaled: 0.0125 (0.0133)  loss_giou_unscaled: 0.1180 (0.1337)  cardinality_error_unscaled: 3867.0000 (2771.5305)  loss_ce_0_unscaled: 0.4831 (0.6254)  loss_bbox_0_unscaled: 0.0127 (0.0133)  loss_giou_0_unscaled: 0.1229 (0.1337)  cardinality_error_0_unscaled: 3827.0000 (2870.3969)  loss_ce_1_unscaled: 0.4373 (0.6570)  loss_bbox_1_unscaled: 0.0127 (0.0134)  loss_giou_1_unscaled: 0.1174 (0.1347)  cardinality_error_1_unscaled: 3887.5000 (2913.5458)  loss_ce_enc_unscaled: 0.4848 (0.6252)  loss_bbox_enc_unscaled: 0.0120 (0.0142)  loss_giou_enc_unscaled: 0.1309 (0.1435)  cardinality_error_enc_unscaled: 3766.0000 (2922.9122)  time: 0.8037  data: 0.0185  max mem: 13413
# Epoch: [0]  [140/890]  eta: 0:10:13  lr: 0.000010  class_error: 100.00  loss: 3.0029 (3.8352)  loss_ce: 0.3875 (0.6379)  loss_bbox: 0.0579 (0.0649)  loss_giou: 0.2317 (0.2646)  loss_ce_0: 0.4314 (0.6084)  loss_bbox_0: 0.0604 (0.0649)  loss_giou_0: 0.2401 (0.2640)  loss_ce_1: 0.3962 (0.6359)  loss_bbox_1: 0.0605 (0.0656)  loss_giou_1: 0.2331 (0.2666)  loss_ce_enc: 0.4743 (0.6093)  loss_bbox_enc: 0.0598 (0.0698)  loss_giou_enc: 0.2522 (0.2835)  loss_ce_unscaled: 0.3875 (0.6379)  class_error_unscaled: 0.0000 (26.2593)  loss_bbox_unscaled: 0.0116 (0.0130)  loss_giou_unscaled: 0.1159 (0.1323)  cardinality_error_unscaled: 2316.0000 (2764.0532)  loss_ce_0_unscaled: 0.4314 (0.6084)  loss_bbox_0_unscaled: 0.0121 (0.0130)  loss_giou_0_unscaled: 0.1201 (0.1320)  cardinality_error_0_unscaled: 2756.0000 (2859.2376)  loss_ce_1_unscaled: 0.3962 (0.6359)  loss_bbox_1_unscaled: 0.0121 (0.0131)  loss_giou_1_unscaled: 0.1165 (0.1333)  cardinality_error_1_unscaled: 2619.5000 (2903.3369)  loss_ce_enc_unscaled: 0.4743 (0.6093)  loss_bbox_enc_unscaled: 0.0120 (0.0140)  loss_giou_enc_unscaled: 0.1261 (0.1417)  cardinality_error_enc_unscaled: 2671.5000 (2912.7234)  time: 0.8006  data: 0.0173  max mem: 13413
# Epoch: [0]  [150/890]  eta: 0:10:05  lr: 0.000010  class_error: 50.00  loss: 2.9203 (3.8150)  loss_ce: 0.3640 (0.6264)  loss_bbox: 0.0566 (0.0654)  loss_giou: 0.2457 (0.2690)  loss_ce_0: 0.4622 (0.5989)  loss_bbox_0: 0.0538 (0.0654)  loss_giou_0: 0.2403 (0.2684)  loss_ce_1: 0.3644 (0.6242)  loss_bbox_1: 0.0542 (0.0661)  loss_giou_1: 0.2461 (0.2710)  loss_ce_enc: 0.4743 (0.6013)  loss_bbox_enc: 0.0682 (0.0705)  loss_giou_enc: 0.2694 (0.2883)  loss_ce_unscaled: 0.3640 (0.6264)  class_error_unscaled: 0.0000 (25.5137)  loss_bbox_unscaled: 0.0113 (0.0131)  loss_giou_unscaled: 0.1228 (0.1345)  cardinality_error_unscaled: 3894.5000 (2796.3245)  loss_ce_0_unscaled: 0.4622 (0.5989)  loss_bbox_0_unscaled: 0.0108 (0.0131)  loss_giou_0_unscaled: 0.1201 (0.1342)  cardinality_error_0_unscaled: 3862.5000 (2889.4536)  loss_ce_1_unscaled: 0.3644 (0.6242)  loss_bbox_1_unscaled: 0.0108 (0.0132)  loss_giou_1_unscaled: 0.1230 (0.1355)  cardinality_error_1_unscaled: 3896.0000 (2937.3775)  loss_ce_enc_unscaled: 0.4743 (0.6013)  loss_bbox_enc_unscaled: 0.0136 (0.0141)  loss_giou_enc_unscaled: 0.1347 (0.1441)  cardinality_error_enc_unscaled: 3896.0000 (2943.5066)  time: 0.8092  data: 0.0151  max mem: 13413
# Epoch: [0]  [160/890]  eta: 0:09:58  lr: 0.000010  class_error: 0.00  loss: 3.3800 (3.8042)  loss_ce: 0.4529 (0.6160)  loss_bbox: 0.0566 (0.0669)  loss_giou: 0.3152 (0.2731)  loss_ce_0: 0.4733 (0.5947)  loss_bbox_0: 0.0538 (0.0668)  loss_giou_0: 0.3113 (0.2724)  loss_ce_1: 0.4514 (0.6139)  loss_bbox_1: 0.0542 (0.0675)  loss_giou_1: 0.3258 (0.2750)  loss_ce_enc: 0.4819 (0.5925)  loss_bbox_enc: 0.0605 (0.0723)  loss_giou_enc: 0.3100 (0.2929)  loss_ce_unscaled: 0.4529 (0.6160)  class_error_unscaled: 0.0000 (25.7923)  loss_bbox_unscaled: 0.0113 (0.0134)  loss_giou_unscaled: 0.1576 (0.1366)  cardinality_error_unscaled: 3894.5000 (2806.5062)  loss_ce_0_unscaled: 0.4733 (0.5947)  loss_bbox_0_unscaled: 0.0108 (0.0134)  loss_giou_0_unscaled: 0.1557 (0.1362)  cardinality_error_0_unscaled: 3878.5000 (2895.8354)  loss_ce_1_unscaled: 0.4514 (0.6139)  loss_bbox_1_unscaled: 0.0108 (0.0135)  loss_giou_1_unscaled: 0.1629 (0.1375)  cardinality_error_1_unscaled: 3896.0000 (2948.6522)  loss_ce_enc_unscaled: 0.4819 (0.5925)  loss_bbox_enc_unscaled: 0.0121 (0.0145)  loss_giou_enc_unscaled: 0.1550 (0.1464)  cardinality_error_enc_unscaled: 3898.0000 (2949.9348)  time: 0.8280  data: 0.0149  max mem: 13413
# Epoch: [0]  [170/890]  eta: 0:09:49  lr: 0.000010  class_error: 0.00  loss: 3.2248 (3.7685)  loss_ce: 0.4274 (0.6050)  loss_bbox: 0.0505 (0.0666)  loss_giou: 0.3092 (0.2741)  loss_ce_0: 0.4733 (0.5876)  loss_bbox_0: 0.0510 (0.0663)  loss_giou_0: 0.3113 (0.2727)  loss_ce_1: 0.4246 (0.6031)  loss_bbox_1: 0.0513 (0.0671)  loss_giou_1: 0.3030 (0.2760)  loss_ce_enc: 0.4529 (0.5848)  loss_bbox_enc: 0.0556 (0.0718)  loss_giou_enc: 0.2897 (0.2933)  loss_ce_unscaled: 0.4274 (0.6050)  class_error_unscaled: 0.0000 (24.2840)  loss_bbox_unscaled: 0.0101 (0.0133)  loss_giou_unscaled: 0.1546 (0.1371)  cardinality_error_unscaled: 3884.0000 (2831.4854)  loss_ce_0_unscaled: 0.4733 (0.5876)  loss_bbox_0_unscaled: 0.0102 (0.0133)  loss_giou_0_unscaled: 0.1557 (0.1363)  cardinality_error_0_unscaled: 3856.0000 (2914.4561)  loss_ce_1_unscaled: 0.4246 (0.6031)  loss_bbox_1_unscaled: 0.0103 (0.0134)  loss_giou_1_unscaled: 0.1515 (0.1380)  cardinality_error_1_unscaled: 3880.0000 (2970.0789)  loss_ce_enc_unscaled: 0.4529 (0.5848)  loss_bbox_enc_unscaled: 0.0111 (0.0144)  loss_giou_enc_unscaled: 0.1449 (0.1467)  cardinality_error_enc_unscaled: 3896.0000 (2970.0175)  time: 0.8230  data: 0.0154  max mem: 13413
# Epoch: [0]  [180/890]  eta: 0:09:39  lr: 0.000010  class_error: 100.00  loss: 3.0062 (3.7341)  loss_ce: 0.4202 (0.5954)  loss_bbox: 0.0622 (0.0664)  loss_giou: 0.2462 (0.2744)  loss_ce_0: 0.4525 (0.5799)  loss_bbox_0: 0.0497 (0.0658)  loss_giou_0: 0.2088 (0.2721)  loss_ce_1: 0.4246 (0.5937)  loss_bbox_1: 0.0550 (0.0667)  loss_giou_1: 0.2330 (0.2758)  loss_ce_enc: 0.4562 (0.5797)  loss_bbox_enc: 0.0612 (0.0713)  loss_giou_enc: 0.2738 (0.2930)  loss_ce_unscaled: 0.4202 (0.5954)  class_error_unscaled: 0.0000 (24.0473)  loss_bbox_unscaled: 0.0124 (0.0133)  loss_giou_unscaled: 0.1231 (0.1372)  cardinality_error_unscaled: 2761.5000 (2827.2597)  loss_ce_0_unscaled: 0.4525 (0.5799)  loss_bbox_0_unscaled: 0.0099 (0.0132)  loss_giou_0_unscaled: 0.1044 (0.1360)  cardinality_error_0_unscaled: 2716.5000 (2909.6768)  loss_ce_1_unscaled: 0.4246 (0.5937)  loss_bbox_1_unscaled: 0.0110 (0.0133)  loss_giou_1_unscaled: 0.1165 (0.1379)  cardinality_error_1_unscaled: 3184.0000 (2970.1685)  loss_ce_enc_unscaled: 0.4562 (0.5797)  loss_bbox_enc_unscaled: 0.0122 (0.0143)  loss_giou_enc_unscaled: 0.1369 (0.1465)  cardinality_error_enc_unscaled: 2831.5000 (2967.6602)  time: 0.7921  data: 0.0152  max mem: 13413
# Epoch: [0]  [190/890]  eta: 0:09:30  lr: 0.000010  class_error: 0.00  loss: 2.6319 (3.6764)  loss_ce: 0.4066 (0.5836)  loss_bbox: 0.0625 (0.0664)  loss_giou: 0.2013 (0.2713)  loss_ce_0: 0.4379 (0.5696)  loss_bbox_0: 0.0497 (0.0660)  loss_giou_0: 0.2052 (0.2693)  loss_ce_1: 0.4031 (0.5821)  loss_bbox_1: 0.0550 (0.0667)  loss_giou_1: 0.1979 (0.2724)  loss_ce_enc: 0.4166 (0.5692)  loss_bbox_enc: 0.0637 (0.0711)  loss_giou_enc: 0.2183 (0.2887)  loss_ce_unscaled: 0.4066 (0.5836)  class_error_unscaled: 0.0000 (23.3119)  loss_bbox_unscaled: 0.0125 (0.0133)  loss_giou_unscaled: 0.1007 (0.1357)  cardinality_error_unscaled: 2761.5000 (2849.6073)  loss_ce_0_unscaled: 0.4379 (0.5696)  loss_bbox_0_unscaled: 0.0099 (0.0132)  loss_giou_0_unscaled: 0.1026 (0.1347)  cardinality_error_0_unscaled: 2716.5000 (2924.1178)  loss_ce_1_unscaled: 0.4031 (0.5821)  loss_bbox_1_unscaled: 0.0110 (0.0133)  loss_giou_1_unscaled: 0.0989 (0.1362)  cardinality_error_1_unscaled: 3184.0000 (2990.7016)  loss_ce_enc_unscaled: 0.4166 (0.5692)  loss_bbox_enc_unscaled: 0.0127 (0.0142)  loss_giou_enc_unscaled: 0.1091 (0.1443)  cardinality_error_enc_unscaled: 2831.5000 (2982.7749)  time: 0.7784  data: 0.0149  max mem: 13413
# Epoch: [0]  [200/890]  eta: 0:09:23  lr: 0.000010  class_error: 100.00  loss: 2.6931 (3.6480)  loss_ce: 0.3922 (0.5766)  loss_bbox: 0.0525 (0.0658)  loss_giou: 0.2022 (0.2694)  loss_ce_0: 0.4058 (0.5628)  loss_bbox_0: 0.0610 (0.0662)  loss_giou_0: 0.2166 (0.2690)  loss_ce_1: 0.3903 (0.5745)  loss_bbox_1: 0.0607 (0.0664)  loss_giou_1: 0.2053 (0.2712)  loss_ce_enc: 0.4166 (0.5660)  loss_bbox_enc: 0.0698 (0.0715)  loss_giou_enc: 0.2503 (0.2886)  loss_ce_unscaled: 0.3922 (0.5766)  class_error_unscaled: 0.0000 (23.1471)  loss_bbox_unscaled: 0.0105 (0.0132)  loss_giou_unscaled: 0.1011 (0.1347)  cardinality_error_unscaled: 2637.0000 (2845.4428)  loss_ce_0_unscaled: 0.4058 (0.5628)  loss_bbox_0_unscaled: 0.0122 (0.0132)  loss_giou_0_unscaled: 0.1083 (0.1345)  cardinality_error_0_unscaled: 2752.0000 (2918.8234)  loss_ce_1_unscaled: 0.3903 (0.5745)  loss_bbox_1_unscaled: 0.0121 (0.0133)  loss_giou_1_unscaled: 0.1027 (0.1356)  cardinality_error_1_unscaled: 3067.5000 (2989.6592)  loss_ce_enc_unscaled: 0.4166 (0.5660)  loss_bbox_enc_unscaled: 0.0140 (0.0143)  loss_giou_enc_unscaled: 0.1251 (0.1443)  cardinality_error_enc_unscaled: 3247.0000 (2982.1716)  time: 0.8241  data: 0.0154  max mem: 13413
# Epoch: [0]  [210/890]  eta: 0:09:15  lr: 0.000010  class_error: 0.00  loss: 3.0629 (3.6311)  loss_ce: 0.4108 (0.5706)  loss_bbox: 0.0502 (0.0655)  loss_giou: 0.2355 (0.2702)  loss_ce_0: 0.4257 (0.5581)  loss_bbox_0: 0.0517 (0.0663)  loss_giou_0: 0.2405 (0.2702)  loss_ce_1: 0.4160 (0.5687)  loss_bbox_1: 0.0529 (0.0665)  loss_giou_1: 0.2478 (0.2720)  loss_ce_enc: 0.5075 (0.5628)  loss_bbox_enc: 0.0679 (0.0710)  loss_giou_enc: 0.2574 (0.2892)  loss_ce_unscaled: 0.4108 (0.5706)  class_error_unscaled: 0.0000 (22.6516)  loss_bbox_unscaled: 0.0100 (0.0131)  loss_giou_unscaled: 0.1177 (0.1351)  cardinality_error_unscaled: 2500.5000 (2836.6896)  loss_ce_0_unscaled: 0.4257 (0.5581)  loss_bbox_0_unscaled: 0.0103 (0.0133)  loss_giou_0_unscaled: 0.1202 (0.1351)  cardinality_error_0_unscaled: 2429.0000 (2910.7891)  loss_ce_1_unscaled: 0.4160 (0.5687)  loss_bbox_1_unscaled: 0.0106 (0.0133)  loss_giou_1_unscaled: 0.1239 (0.1360)  cardinality_error_1_unscaled: 2830.0000 (2981.3033)  loss_ce_enc_unscaled: 0.5075 (0.5628)  loss_bbox_enc_unscaled: 0.0136 (0.0142)  loss_giou_enc_unscaled: 0.1287 (0.1446)  cardinality_error_enc_unscaled: 2885.5000 (2977.4408)  time: 0.8342  data: 0.0156  max mem: 13413
# Epoch: [0]  [220/890]  eta: 0:09:07  lr: 0.000010  class_error: 0.00  loss: 3.4430 (3.6375)  loss_ce: 0.4719 (0.5667)  loss_bbox: 0.0567 (0.0667)  loss_giou: 0.2971 (0.2740)  loss_ce_0: 0.4908 (0.5549)  loss_bbox_0: 0.0646 (0.0675)  loss_giou_0: 0.2974 (0.2741)  loss_ce_1: 0.4768 (0.5648)  loss_bbox_1: 0.0608 (0.0676)  loss_giou_1: 0.2962 (0.2760)  loss_ce_enc: 0.5093 (0.5601)  loss_bbox_enc: 0.0735 (0.0720)  loss_giou_enc: 0.3083 (0.2930)  loss_ce_unscaled: 0.4719 (0.5667)  class_error_unscaled: 0.0000 (22.3054)  loss_bbox_unscaled: 0.0113 (0.0133)  loss_giou_unscaled: 0.1485 (0.1370)  cardinality_error_unscaled: 3887.5000 (2861.6697)  loss_ce_0_unscaled: 0.4908 (0.5549)  loss_bbox_0_unscaled: 0.0129 (0.0135)  loss_giou_0_unscaled: 0.1487 (0.1370)  cardinality_error_0_unscaled: 3805.5000 (2932.6312)  loss_ce_1_unscaled: 0.4768 (0.5648)  loss_bbox_1_unscaled: 0.0122 (0.0135)  loss_giou_1_unscaled: 0.1481 (0.1380)  cardinality_error_1_unscaled: 3859.0000 (3004.2557)  loss_ce_enc_unscaled: 0.5093 (0.5601)  loss_bbox_enc_unscaled: 0.0147 (0.0144)  loss_giou_enc_unscaled: 0.1541 (0.1465)  cardinality_error_enc_unscaled: 3896.5000 (2997.6109)  time: 0.8137  data: 0.0155  max mem: 13413
# Epoch: [0]  [230/890]  eta: 0:08:59  lr: 0.000010  class_error: 0.00  loss: 3.3978 (3.5946)  loss_ce: 0.4221 (0.5576)  loss_bbox: 0.0762 (0.0667)  loss_giou: 0.2646 (0.2716)  loss_ce_0: 0.4087 (0.5464)  loss_bbox_0: 0.0807 (0.0675)  loss_giou_0: 0.2730 (0.2720)  loss_ce_1: 0.4153 (0.5556)  loss_bbox_1: 0.0772 (0.0675)  loss_giou_1: 0.2573 (0.2735)  loss_ce_enc: 0.4754 (0.5529)  loss_bbox_enc: 0.0751 (0.0723)  loss_giou_enc: 0.2918 (0.2911)  loss_ce_unscaled: 0.4221 (0.5576)  class_error_unscaled: 0.0000 (22.2056)  loss_bbox_unscaled: 0.0152 (0.0133)  loss_giou_unscaled: 0.1323 (0.1358)  cardinality_error_unscaled: 3887.5000 (2872.6623)  loss_ce_0_unscaled: 0.4087 (0.5464)  loss_bbox_0_unscaled: 0.0161 (0.0135)  loss_giou_0_unscaled: 0.1365 (0.1360)  cardinality_error_0_unscaled: 3835.0000 (2936.9719)  loss_ce_1_unscaled: 0.4153 (0.5556)  loss_bbox_1_unscaled: 0.0154 (0.0135)  loss_giou_1_unscaled: 0.1287 (0.1367)  cardinality_error_1_unscaled: 3869.0000 (3013.2208)  loss_ce_enc_unscaled: 0.4754 (0.5529)  loss_bbox_enc_unscaled: 0.0150 (0.0145)  loss_giou_enc_unscaled: 0.1459 (0.1456)  cardinality_error_enc_unscaled: 3893.0000 (3004.3528)  time: 0.8290  data: 0.0152  max mem: 13413
# Epoch: [0]  [240/890]  eta: 0:08:52  lr: 0.000010  class_error: 100.00  loss: 2.6306 (3.5295)  loss_ce: 0.3689 (0.5461)  loss_bbox: 0.0442 (0.0654)  loss_giou: 0.2148 (0.2680)  loss_ce_0: 0.3800 (0.5356)  loss_bbox_0: 0.0483 (0.0662)  loss_giou_0: 0.2196 (0.2684)  loss_ce_1: 0.3666 (0.5441)  loss_bbox_1: 0.0441 (0.0662)  loss_giou_1: 0.2144 (0.2697)  loss_ce_enc: 0.3816 (0.5419)  loss_bbox_enc: 0.0498 (0.0708)  loss_giou_enc: 0.2515 (0.2872)  loss_ce_unscaled: 0.3689 (0.5461)  class_error_unscaled: 0.0000 (22.5290)  loss_bbox_unscaled: 0.0088 (0.0131)  loss_giou_unscaled: 0.1074 (0.1340)  cardinality_error_unscaled: 2678.0000 (2862.5436)  loss_ce_0_unscaled: 0.3800 (0.5356)  loss_bbox_0_unscaled: 0.0097 (0.0132)  loss_giou_0_unscaled: 0.1098 (0.1342)  cardinality_error_0_unscaled: 2408.0000 (2931.1867)  loss_ce_1_unscaled: 0.3666 (0.5441)  loss_bbox_1_unscaled: 0.0088 (0.0132)  loss_giou_1_unscaled: 0.1072 (0.1348)  cardinality_error_1_unscaled: 2990.0000 (3004.9938)  loss_ce_enc_unscaled: 0.3816 (0.5419)  loss_bbox_enc_unscaled: 0.0100 (0.0142)  loss_giou_enc_unscaled: 0.1258 (0.1436)  cardinality_error_enc_unscaled: 2850.0000 (2998.5705)  time: 0.8390  data: 0.0149  max mem: 13413
# Epoch: [0]  [280/890]  eta: 0:08:17  lr: 0.000010  class_error: 0.00  loss: 3.9917 (3.5127)  loss_ce: 0.4943 (0.5385)  loss_bbox: 0.0721 (0.0658)  loss_giou: 0.3389 (0.2693)  loss_ce_0: 0.5113 (0.5312)  loss_bbox_0: 0.0744 (0.0670)  loss_giou_0: 0.3483 (0.2708)  loss_ce_1: 0.4951 (0.5376)  loss_bbox_1: 0.0718 (0.0665)  loss_giou_1: 0.3107 (0.2709)  loss_ce_enc: 0.5401 (0.5372)  loss_bbox_enc: 0.0774 (0.0707)  loss_giou_enc: 0.3583 (0.2871)  loss_ce_unscaled: 0.4943 (0.5385)  class_error_unscaled: 0.0000 (21.8268)  loss_bbox_unscaled: 0.0144 (0.0132)  loss_giou_unscaled: 0.1695 (0.1347)  cardinality_error_unscaled: 3037.0000 (2845.2918)  loss_ce_0_unscaled: 0.5113 (0.5312)  loss_bbox_0_unscaled: 0.0149 (0.0134)  loss_giou_0_unscaled: 0.1741 (0.1354)  cardinality_error_0_unscaled: 2854.0000 (2915.8238)  loss_ce_1_unscaled: 0.4951 (0.5376)  loss_bbox_1_unscaled: 0.0144 (0.0133)  loss_giou_1_unscaled: 0.1554 (0.1354)  cardinality_error_1_unscaled: 3389.0000 (2993.0569)  loss_ce_enc_unscaled: 0.5401 (0.5372)  loss_bbox_enc_unscaled: 0.0155 (0.0141)  loss_giou_enc_unscaled: 0.1791 (0.1435)  cardinality_error_enc_unscaled: 2976.5000 (2982.8790)  time: 0.7861  data: 0.0151  max mem: 13413
# Epoch: [0]  [290/890]  eta: 0:08:09  lr: 0.000010  class_error: 0.00  loss: 3.5416 (3.5055)  loss_ce: 0.4424 (0.5368)  loss_bbox: 0.0665 (0.0662)  loss_giou: 0.3019 (0.2691)  loss_ce_0: 0.4567 (0.5287)  loss_bbox_0: 0.0657 (0.0675)  loss_giou_0: 0.2985 (0.2709)  loss_ce_1: 0.4505 (0.5352)  loss_bbox_1: 0.0657 (0.0668)  loss_giou_1: 0.2978 (0.2705)  loss_ce_enc: 0.4995 (0.5360)  loss_bbox_enc: 0.0714 (0.0710)  loss_giou_enc: 0.3081 (0.2869)  loss_ce_unscaled: 0.4424 (0.5368)  class_error_unscaled: 0.0000 (22.1077)  loss_bbox_unscaled: 0.0133 (0.0132)  loss_giou_unscaled: 0.1509 (0.1345)  cardinality_error_unscaled: 2495.0000 (2839.4141)  loss_ce_0_unscaled: 0.4567 (0.5287)  loss_bbox_0_unscaled: 0.0131 (0.0135)  loss_giou_0_unscaled: 0.1492 (0.1354)  cardinality_error_0_unscaled: 2610.5000 (2909.5447)  loss_ce_1_unscaled: 0.4505 (0.5352)  loss_bbox_1_unscaled: 0.0131 (0.0134)  loss_giou_1_unscaled: 0.1489 (0.1353)  cardinality_error_1_unscaled: 2911.0000 (2987.1186)  loss_ce_enc_unscaled: 0.4995 (0.5360)  loss_bbox_enc_unscaled: 0.0143 (0.0142)  loss_giou_enc_unscaled: 0.1540 (0.1435)  cardinality_error_enc_unscaled: 3175.5000 (2977.0481)  time: 0.7943  data: 0.0152  max mem: 13413
# Epoch: [0]  [300/890]  eta: 0:08:02  lr: 0.000010  class_error: 0.00  loss: 3.5416 (3.5067)  loss_ce: 0.4771 (0.5353)  loss_bbox: 0.0674 (0.0664)  loss_giou: 0.2856 (0.2701)  loss_ce_0: 0.4695 (0.5307)  loss_bbox_0: 0.0675 (0.0677)  loss_giou_0: 0.2866 (0.2720)  loss_ce_1: 0.4709 (0.5336)  loss_bbox_1: 0.0662 (0.0670)  loss_giou_1: 0.2893 (0.2716)  loss_ce_enc: 0.4854 (0.5329)  loss_bbox_enc: 0.0789 (0.0713)  loss_giou_enc: 0.3078 (0.2880)  loss_ce_unscaled: 0.4771 (0.5353)  class_error_unscaled: 0.0000 (22.0377)  loss_bbox_unscaled: 0.0135 (0.0133)  loss_giou_unscaled: 0.1428 (0.1351)  cardinality_error_unscaled: 2495.0000 (2844.5116)  loss_ce_0_unscaled: 0.4695 (0.5307)  loss_bbox_0_unscaled: 0.0135 (0.0135)  loss_giou_0_unscaled: 0.1433 (0.1360)  cardinality_error_0_unscaled: 2610.5000 (2913.7193)  loss_ce_1_unscaled: 0.4709 (0.5336)  loss_bbox_1_unscaled: 0.0132 (0.0134)  loss_giou_1_unscaled: 0.1447 (0.1358)  cardinality_error_1_unscaled: 2911.0000 (2990.7143)  loss_ce_enc_unscaled: 0.4854 (0.5329)  loss_bbox_enc_unscaled: 0.0158 (0.0143)  loss_giou_enc_unscaled: 0.1539 (0.1440)  cardinality_error_enc_unscaled: 3175.5000 (2981.1761)  time: 0.8469  data: 0.0421  max mem: 13413
# Epoch: [0]  [310/890]  eta: 0:07:54  lr: 0.000010  class_error: 100.00  loss: 3.1116 (3.4799)  loss_ce: 0.4471 (0.5303)  loss_bbox: 0.0517 (0.0658)  loss_giou: 0.2521 (0.2689)  loss_ce_0: 0.4539 (0.5260)  loss_bbox_0: 0.0552 (0.0671)  loss_giou_0: 0.2629 (0.2707)  loss_ce_1: 0.4541 (0.5287)  loss_bbox_1: 0.0528 (0.0664)  loss_giou_1: 0.2653 (0.2703)  loss_ce_enc: 0.4442 (0.5283)  loss_bbox_enc: 0.0637 (0.0708)  loss_giou_enc: 0.2769 (0.2866)  loss_ce_unscaled: 0.4471 (0.5303)  class_error_unscaled: 0.0000 (21.9721)  loss_bbox_unscaled: 0.0103 (0.0132)  loss_giou_unscaled: 0.1261 (0.1344)  cardinality_error_unscaled: 3888.0000 (2860.9582)  loss_ce_0_unscaled: 0.4539 (0.5260)  loss_bbox_0_unscaled: 0.0110 (0.0134)  loss_giou_0_unscaled: 0.1314 (0.1353)  cardinality_error_0_unscaled: 3884.0000 (2928.2379)  loss_ce_1_unscaled: 0.4541 (0.5287)  loss_bbox_1_unscaled: 0.0106 (0.0133)  loss_giou_1_unscaled: 0.1327 (0.1352)  cardinality_error_1_unscaled: 3894.5000 (3005.3023)  loss_ce_enc_unscaled: 0.4442 (0.5283)  loss_bbox_enc_unscaled: 0.0127 (0.0142)  loss_giou_enc_unscaled: 0.1384 (0.1433)  cardinality_error_enc_unscaled: 3895.0000 (2996.1559)  time: 0.8374  data: 0.0419  max mem: 13413
# Epoch: [0]  [320/890]  eta: 0:07:46  lr: 0.000010  class_error: 100.00  loss: 2.5463 (3.4172)  loss_ce: 0.3723 (0.5202)  loss_bbox: 0.0384 (0.0647)  loss_giou: 0.2181 (0.2645)  loss_ce_0: 0.3578 (0.5164)  loss_bbox_0: 0.0360 (0.0658)  loss_giou_0: 0.2038 (0.2661)  loss_ce_1: 0.3673 (0.5186)  loss_bbox_1: 0.0360 (0.0652)  loss_giou_1: 0.2160 (0.2658)  loss_ce_enc: 0.3727 (0.5186)  loss_bbox_enc: 0.0429 (0.0695)  loss_giou_enc: 0.2100 (0.2817)  loss_ce_unscaled: 0.3723 (0.5202)  class_error_unscaled: 0.0000 (22.8453)  loss_bbox_unscaled: 0.0077 (0.0129)  loss_giou_unscaled: 0.1091 (0.1322)  cardinality_error_unscaled: 3873.5000 (2853.4283)  loss_ce_0_unscaled: 0.3578 (0.5164)  loss_bbox_0_unscaled: 0.0072 (0.0132)  loss_giou_0_unscaled: 0.1019 (0.1330)  cardinality_error_0_unscaled: 3849.5000 (2921.3941)  loss_ce_1_unscaled: 0.3673 (0.5186)  loss_bbox_1_unscaled: 0.0072 (0.0130)  loss_giou_1_unscaled: 0.1080 (0.1329)  cardinality_error_1_unscaled: 3887.5000 (3000.1308)  loss_ce_enc_unscaled: 0.3727 (0.5186)  loss_bbox_enc_unscaled: 0.0086 (0.0139)  loss_giou_enc_unscaled: 0.1050 (0.1409)  cardinality_error_enc_unscaled: 3896.0000 (2989.3427)  time: 0.8215  data: 0.0149  max mem: 13413
# Epoch: [0]  [330/890]  eta: 0:07:38  lr: 0.000010  class_error: -0.00  loss: 2.1625 (3.3921)  loss_ce: 0.3270 (0.5156)  loss_bbox: 0.0302 (0.0643)  loss_giou: 0.1795 (0.2632)  loss_ce_0: 0.3241 (0.5124)  loss_bbox_0: 0.0289 (0.0654)  loss_giou_0: 0.1874 (0.2645)  loss_ce_1: 0.3211 (0.5139)  loss_bbox_1: 0.0311 (0.0648)  loss_giou_1: 0.1866 (0.2646)  loss_ce_enc: 0.2971 (0.5140)  loss_bbox_enc: 0.0290 (0.0691)  loss_giou_enc: 0.1491 (0.2803)  loss_ce_unscaled: 0.3270 (0.5156)  class_error_unscaled: 0.0000 (23.3635)  loss_bbox_unscaled: 0.0060 (0.0129)  loss_giou_unscaled: 0.0898 (0.1316)  cardinality_error_unscaled: 2064.0000 (2846.2160)  loss_ce_0_unscaled: 0.3241 (0.5124)  loss_bbox_0_unscaled: 0.0058 (0.0131)  loss_giou_0_unscaled: 0.0937 (0.1322)  cardinality_error_0_unscaled: 2376.5000 (2913.4079)  loss_ce_1_unscaled: 0.3211 (0.5139)  loss_bbox_1_unscaled: 0.0062 (0.0130)  loss_giou_1_unscaled: 0.0933 (0.1323)  cardinality_error_1_unscaled: 2545.5000 (2993.7085)  loss_ce_enc_unscaled: 0.2971 (0.5140)  loss_bbox_enc_unscaled: 0.0058 (0.0138)  loss_giou_enc_unscaled: 0.0746 (0.1401)  cardinality_error_enc_unscaled: 2339.0000 (2981.8202)  time: 0.8380  data: 0.0147  max mem: 13413
# Epoch: [0]  [340/890]  eta: 0:07:29  lr: 0.000010  class_error: 100.00  loss: 3.1418 (3.4035)  loss_ce: 0.4749 (0.5149)  loss_bbox: 0.0575 (0.0653)  loss_giou: 0.2260 (0.2655)  loss_ce_0: 0.4992 (0.5126)  loss_bbox_0: 0.0607 (0.0664)  loss_giou_0: 0.2576 (0.2667)  loss_ce_1: 0.4722 (0.5134)  loss_bbox_1: 0.0594 (0.0658)  loss_giou_1: 0.2352 (0.2668)  loss_ce_enc: 0.5335 (0.5139)  loss_bbox_enc: 0.0707 (0.0702)  loss_giou_enc: 0.2389 (0.2822)  loss_ce_unscaled: 0.4749 (0.5149)  class_error_unscaled: 0.0000 (22.9717)  loss_bbox_unscaled: 0.0115 (0.0131)  loss_giou_unscaled: 0.1130 (0.1327)  cardinality_error_unscaled: 2309.5000 (2854.8314)  loss_ce_0_unscaled: 0.4992 (0.5126)  loss_bbox_0_unscaled: 0.0121 (0.0133)  loss_giou_0_unscaled: 0.1288 (0.1333)  cardinality_error_0_unscaled: 2630.5000 (2921.2669)  loss_ce_1_unscaled: 0.4722 (0.5134)  loss_bbox_1_unscaled: 0.0119 (0.0132)  loss_giou_1_unscaled: 0.1176 (0.1334)  cardinality_error_1_unscaled: 2673.5000 (3000.4619)  loss_ce_enc_unscaled: 0.5335 (0.5139)  loss_bbox_enc_unscaled: 0.0141 (0.0140)  loss_giou_enc_unscaled: 0.1195 (0.1411)  cardinality_error_enc_unscaled: 2900.0000 (2990.9604)  time: 0.8010  data: 0.0149  max mem: 13413
# Epoch: [0]  [350/890]  eta: 0:07:21  lr: 0.000010  class_error: 0.00  loss: 3.9743 (3.4101)  loss_ce: 0.5503 (0.5140)  loss_bbox: 0.0648 (0.0662)  loss_giou: 0.3179 (0.2672)  loss_ce_0: 0.5628 (0.5121)  loss_bbox_0: 0.0622 (0.0673)  loss_giou_0: 0.3271 (0.2685)  loss_ce_1: 0.5459 (0.5125)  loss_bbox_1: 0.0633 (0.0666)  loss_giou_1: 0.3210 (0.2683)  loss_ce_enc: 0.5489 (0.5128)  loss_bbox_enc: 0.0738 (0.0709)  loss_giou_enc: 0.2983 (0.2837)  loss_ce_unscaled: 0.5503 (0.5140)  class_error_unscaled: 0.0000 (22.8870)  loss_bbox_unscaled: 0.0130 (0.0132)  loss_giou_unscaled: 0.1590 (0.1336)  cardinality_error_unscaled: 3792.5000 (2856.9972)  loss_ce_0_unscaled: 0.5628 (0.5121)  loss_bbox_0_unscaled: 0.0124 (0.0135)  loss_giou_0_unscaled: 0.1636 (0.1343)  cardinality_error_0_unscaled: 3825.0000 (2923.6353)  loss_ce_1_unscaled: 0.5459 (0.5125)  loss_bbox_1_unscaled: 0.0127 (0.0133)  loss_giou_1_unscaled: 0.1605 (0.1342)  cardinality_error_1_unscaled: 3896.5000 (3000.7479)  loss_ce_enc_unscaled: 0.5489 (0.5128)  loss_bbox_enc_unscaled: 0.0148 (0.0142)  loss_giou_enc_unscaled: 0.1491 (0.1418)  cardinality_error_enc_unscaled: 3881.5000 (2991.9758)  time: 0.7820  data: 0.0164  max mem: 13413
# Epoch: [0]  [360/890]  eta: 0:07:12  lr: 0.000010  class_error: 0.00  loss: 3.4272 (3.4904)  loss_ce: 0.4388 (0.5374)  loss_bbox: 0.0648 (0.0659)  loss_giou: 0.2593 (0.2664)  loss_ce_0: 0.4485 (0.5425)  loss_bbox_0: 0.0612 (0.0670)  loss_giou_0: 0.2536 (0.2677)  loss_ce_1: 0.4380 (0.5370)  loss_bbox_1: 0.0633 (0.0663)  loss_giou_1: 0.2496 (0.2675)  loss_ce_enc: 0.4559 (0.5197)  loss_bbox_enc: 0.0567 (0.0705)  loss_giou_enc: 0.2957 (0.2825)  loss_ce_unscaled: 0.4388 (0.5374)  class_error_unscaled: 0.0000 (22.8070)  loss_bbox_unscaled: 0.0130 (0.0132)  loss_giou_unscaled: 0.1297 (0.1332)  cardinality_error_unscaled: 2399.0000 (2848.0194)  loss_ce_0_unscaled: 0.4485 (0.5425)  loss_bbox_0_unscaled: 0.0122 (0.0134)  loss_giou_0_unscaled: 0.1268 (0.1339)  cardinality_error_0_unscaled: 2420.0000 (2915.0346)  loss_ce_1_unscaled: 0.4380 (0.5370)  loss_bbox_1_unscaled: 0.0127 (0.0133)  loss_giou_1_unscaled: 0.1248 (0.1338)  cardinality_error_1_unscaled: 2861.5000 (2994.0873)  loss_ce_enc_unscaled: 0.4559 (0.5197)  loss_bbox_enc_unscaled: 0.0113 (0.0141)  loss_giou_enc_unscaled: 0.1479 (0.1413)  cardinality_error_enc_unscaled: 2753.0000 (2987.6136)  time: 0.7959  data: 0.0173  max mem: 13413
# Epoch: [0]  [370/890]  eta: 0:07:04  lr: 0.000010  class_error: 0.00  loss: 3.4272 (3.4847)  loss_ce: 0.4368 (0.5341)  loss_bbox: 0.0659 (0.0659)  loss_giou: 0.2593 (0.2681)  loss_ce_0: 0.4485 (0.5395)  loss_bbox_0: 0.0619 (0.0669)  loss_giou_0: 0.2536 (0.2693)  loss_ce_1: 0.4321 (0.5338)  loss_bbox_1: 0.0657 (0.0663)  loss_giou_1: 0.2514 (0.2692)  loss_ce_enc: 0.4488 (0.5174)  loss_bbox_enc: 0.0705 (0.0704)  loss_giou_enc: 0.2721 (0.2838)  loss_ce_unscaled: 0.4368 (0.5341)  class_error_unscaled: 0.0000 (22.4618)  loss_bbox_unscaled: 0.0132 (0.0132)  loss_giou_unscaled: 0.1297 (0.1341)  cardinality_error_unscaled: 2682.0000 (2864.4313)  loss_ce_0_unscaled: 0.4485 (0.5395)  loss_bbox_0_unscaled: 0.0124 (0.0134)  loss_giou_0_unscaled: 0.1268 (0.1347)  cardinality_error_0_unscaled: 2805.0000 (2930.2278)  loss_ce_1_unscaled: 0.4321 (0.5338)  loss_bbox_1_unscaled: 0.0131 (0.0133)  loss_giou_1_unscaled: 0.1257 (0.1346)  cardinality_error_1_unscaled: 3121.5000 (3009.8787)  loss_ce_enc_unscaled: 0.4488 (0.5174)  loss_bbox_enc_unscaled: 0.0141 (0.0141)  loss_giou_enc_unscaled: 0.1360 (0.1419)  cardinality_error_enc_unscaled: 3026.0000 (3001.8315)  time: 0.8073  data: 0.0181  max mem: 13413
# Epoch: [0]  [380/890]  eta: 0:06:55  lr: 0.000010  class_error: 0.00  loss: 2.8879 (3.4636)  loss_ce: 0.4005 (0.5296)  loss_bbox: 0.0637 (0.0657)  loss_giou: 0.2147 (0.2664)  loss_ce_0: 0.4348 (0.5353)  loss_bbox_0: 0.0619 (0.0668)  loss_giou_0: 0.2313 (0.2677)  loss_ce_1: 0.4048 (0.5293)  loss_bbox_1: 0.0624 (0.0662)  loss_giou_1: 0.2180 (0.2674)  loss_ce_enc: 0.4498 (0.5159)  loss_bbox_enc: 0.0785 (0.0706)  loss_giou_enc: 0.2561 (0.2827)  loss_ce_unscaled: 0.4005 (0.5296)  class_error_unscaled: 0.0000 (22.1347)  loss_bbox_unscaled: 0.0127 (0.0131)  loss_giou_unscaled: 0.1074 (0.1332)  cardinality_error_unscaled: 3839.0000 (2870.0643)  loss_ce_0_unscaled: 0.4348 (0.5353)  loss_bbox_0_unscaled: 0.0124 (0.0134)  loss_giou_0_unscaled: 0.1156 (0.1339)  cardinality_error_0_unscaled: 3778.0000 (2934.1588)  loss_ce_1_unscaled: 0.4048 (0.5293)  loss_bbox_1_unscaled: 0.0125 (0.0132)  loss_giou_1_unscaled: 0.1090 (0.1337)  cardinality_error_1_unscaled: 3887.5000 (3016.6102)  loss_ce_enc_unscaled: 0.4498 (0.5159)  loss_bbox_enc_unscaled: 0.0157 (0.0141)  loss_giou_enc_unscaled: 0.1280 (0.1413)  cardinality_error_enc_unscaled: 3894.0000 (3007.7598)  time: 0.7970  data: 0.0175  max mem: 13413
# ...
# Test:  [540/569]  eta: 0:00:01  class_error: 0.00  loss: 4.4404 (4.4732)  loss_ce: 0.6094 (0.6210)  loss_bbox: 0.0965 (0.0928)  loss_giou: 0.4351 (0.3970)  loss_ce_0: 0.5977 (0.6252)  loss_bbox_0: 0.0883 (0.0928)  loss_giou_0: 0.4339 (0.3970)  loss_ce_1: 0.5938 (0.6220)  loss_bbox_1: 0.0931 (0.0930)  loss_giou_1: 0.4233 (0.3966)  loss_ce_enc: 0.5664 (0.6259)  loss_bbox_enc: 0.1030 (0.0961)  loss_giou_enc: 0.4371 (0.4138)  loss_ce_unscaled: 0.6094 (0.6210)  class_error_unscaled: 0.0000 (7.0643)  loss_bbox_unscaled: 0.0193 (0.0186)  loss_giou_unscaled: 0.2176 (0.1985)  cardinality_error_unscaled: 2.5000 (236.4695)  loss_ce_0_unscaled: 0.5977 (0.6252)  loss_bbox_0_unscaled: 0.0177 (0.0186)  loss_giou_0_unscaled: 0.2170 (0.1985)  cardinality_error_0_unscaled: 36.0000 (244.5342)  loss_ce_1_unscaled: 0.5938 (0.6220)  loss_bbox_1_unscaled: 0.0186 (0.0186)  loss_giou_1_unscaled: 0.2116 (0.1983)  cardinality_error_1_unscaled: 29.0000 (243.3882)  loss_ce_enc_unscaled: 0.5664 (0.6259)  loss_bbox_enc_unscaled: 0.0206 (0.0192)  loss_giou_enc_unscaled: 0.2186 (0.2069)  cardinality_error_enc_unscaled: 75.0000 (251.1895)  time: 0.0454  data: 0.0048  max mem: 13413
# Test:  [550/569]  eta: 0:00:00  class_error: 0.00  loss: 4.4898 (4.4801)  loss_ce: 0.5742 (0.6201)  loss_bbox: 0.1100 (0.0937)  loss_giou: 0.4544 (0.3987)  loss_ce_0: 0.5859 (0.6245)  loss_bbox_0: 0.1120 (0.0938)  loss_giou_0: 0.4607 (0.3987)  loss_ce_1: 0.5703 (0.6211)  loss_bbox_1: 0.1095 (0.0939)  loss_giou_1: 0.4695 (0.3984)  loss_ce_enc: 0.5742 (0.6251)  loss_bbox_enc: 0.1090 (0.0969)  loss_giou_enc: 0.4569 (0.4152)  loss_ce_unscaled: 0.5742 (0.6201)  class_error_unscaled: 0.0000 (7.0268)  loss_bbox_unscaled: 0.0220 (0.0187)  loss_giou_unscaled: 0.2272 (0.1994)  cardinality_error_unscaled: 2.5000 (232.3675)  loss_ce_0_unscaled: 0.5859 (0.6245)  loss_bbox_0_unscaled: 0.0224 (0.0188)  loss_giou_0_unscaled: 0.2304 (0.1994)  cardinality_error_0_unscaled: 72.0000 (241.3367)  loss_ce_1_unscaled: 0.5703 (0.6211)  loss_bbox_1_unscaled: 0.0219 (0.0188)  loss_giou_1_unscaled: 0.2347 (0.1992)  cardinality_error_1_unscaled: 35.5000 (239.8693)  loss_ce_enc_unscaled: 0.5742 (0.6251)  loss_bbox_enc_unscaled: 0.0218 (0.0194)  loss_giou_enc_unscaled: 0.2285 (0.2076)  cardinality_error_enc_unscaled: 85.0000 (248.2060)  time: 0.0465  data: 0.0048  max mem: 13413
# Test:  [560/569]  eta: 0:00:00  class_error: 0.00  loss: 3.8022 (4.4627)  loss_ce: 0.4785 (0.6169)  loss_bbox: 0.1022 (0.0937)  loss_giou: 0.3846 (0.3974)  loss_ce_0: 0.4668 (0.6210)  loss_bbox_0: 0.1120 (0.0940)  loss_giou_0: 0.4000 (0.3978)  loss_ce_1: 0.4746 (0.6178)  loss_bbox_1: 0.1095 (0.0939)  loss_giou_1: 0.3924 (0.3973)  loss_ce_enc: 0.4590 (0.6218)  loss_bbox_enc: 0.1090 (0.0970)  loss_giou_enc: 0.3860 (0.4140)  loss_ce_unscaled: 0.4785 (0.6169)  class_error_unscaled: 0.0000 (6.9016)  loss_bbox_unscaled: 0.0204 (0.0187)  loss_giou_unscaled: 0.1923 (0.1987)  cardinality_error_unscaled: 2.5000 (228.2825)  loss_ce_0_unscaled: 0.4668 (0.6210)  loss_bbox_0_unscaled: 0.0224 (0.0188)  loss_giou_0_unscaled: 0.2000 (0.1989)  cardinality_error_0_unscaled: 21.0000 (237.3592)  loss_ce_1_unscaled: 0.4746 (0.6178)  loss_bbox_1_unscaled: 0.0219 (0.0188)  loss_giou_1_unscaled: 0.1962 (0.1986)  cardinality_error_1_unscaled: 20.0000 (235.9162)  loss_ce_enc_unscaled: 0.4590 (0.6218)  loss_bbox_enc_unscaled: 0.0218 (0.0194)  loss_giou_enc_unscaled: 0.1930 (0.2070)  cardinality_error_enc_unscaled: 58.5000 (244.7032)  time: 0.0466  data: 0.0048  max mem: 13413
# Test:  [568/569]  eta: 0:00:00  class_error: 0.00  loss: 4.2208 (4.4751)  loss_ce: 0.5273 (0.6170)  loss_bbox: 0.0917 (0.0939)  loss_giou: 0.4511 (0.3999)  loss_ce_0: 0.5156 (0.6215)  loss_bbox_0: 0.1102 (0.0943)  loss_giou_0: 0.4582 (0.4005)  loss_ce_1: 0.4941 (0.6178)  loss_bbox_1: 0.0975 (0.0941)  loss_giou_1: 0.4479 (0.3998)  loss_ce_enc: 0.4844 (0.6219)  loss_bbox_enc: 0.0967 (0.0974)  loss_giou_enc: 0.4110 (0.4169)  loss_ce_unscaled: 0.5273 (0.6170)  class_error_unscaled: 0.0000 (6.8045)  loss_bbox_unscaled: 0.0183 (0.0188)  loss_giou_unscaled: 0.2256 (0.1999)  cardinality_error_unscaled: 3.0000 (225.1661)  loss_ce_0_unscaled: 0.5156 (0.6215)  loss_bbox_0_unscaled: 0.0220 (0.0189)  loss_giou_0_unscaled: 0.2291 (0.2002)  cardinality_error_0_unscaled: 19.0000 (234.3120)  loss_ce_1_unscaled: 0.4941 (0.6178)  loss_bbox_1_unscaled: 0.0195 (0.0188)  loss_giou_1_unscaled: 0.2239 (0.1999)  cardinality_error_1_unscaled: 19.5000 (232.9051)  loss_ce_enc_unscaled: 0.4844 (0.6219)  loss_bbox_enc_unscaled: 0.0193 (0.0195)  loss_giou_enc_unscaled: 0.2055 (0.2084)  cardinality_error_enc_unscaled: 50.5000 (241.8128)  time: 0.0456  data: 0.0048  max mem: 13413
# Test: Total time: 0:00:27 (0.0483 s / it)
# Averaged stats: class_error: 0.00  loss: 4.2208 (4.4751)  loss_ce: 0.5273 (0.6170)  loss_bbox: 0.0917 (0.0939)  loss_giou: 0.4511 (0.3999)  loss_ce_0: 0.5156 (0.6215)  loss_bbox_0: 0.1102 (0.0943)  loss_giou_0: 0.4582 (0.4005)  loss_ce_1: 0.4941 (0.6178)  loss_bbox_1: 0.0975 (0.0941)  loss_giou_1: 0.4479 (0.3998)  loss_ce_enc: 0.4844 (0.6219)  loss_bbox_enc: 0.0967 (0.0974)  loss_giou_enc: 0.4110 (0.4169)  loss_ce_unscaled: 0.5273 (0.6170)  class_error_unscaled: 0.0000 (6.8045)  loss_bbox_unscaled: 0.0183 (0.0188)  loss_giou_unscaled: 0.2256 (0.1999)  cardinality_error_unscaled: 3.0000 (225.1661)  loss_ce_0_unscaled: 0.5156 (0.6215)  loss_bbox_0_unscaled: 0.0220 (0.0189)  loss_giou_0_unscaled: 0.2291 (0.2002)  cardinality_error_0_unscaled: 19.0000 (234.3120)  loss_ce_1_unscaled: 0.4941 (0.6178)  loss_bbox_1_unscaled: 0.0195 (0.0188)  loss_giou_1_unscaled: 0.2239 (0.1999)  cardinality_error_1_unscaled: 19.5000 (232.9051)  loss_ce_enc_unscaled: 0.4844 (0.6219)  loss_bbox_enc_unscaled: 0.0193 (0.0195)  loss_giou_enc_unscaled: 0.2055 (0.2084)  cardinality_error_enc_unscaled: 50.5000 (241.8128)
# Accumulating evaluation results...
# DONE (t=1.12s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.853
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.614
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.317
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.677
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.549
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# WARNING:rfdetr.detr:Model is not optimized for inference. Latency may be higher than expected. You can optimize the model for inference by calling model.optimize_for_inference().
# ======================================================================
# [HerdNet Metrics] Evaluating at epoch 0...
# ======================================================================
#   Evaluating on 1137 images
#   ✓ Processed 1137 images (0 skipped)
#   ✓ Logged HerdNet metrics to WandB (misty-glade-9)
#
# ======================================================================
# HerdNet Metrics @ Epoch 1 (threshold=20px)
# ======================================================================
#
# Overall (Binary Detection):
#   F1:        0.9090
#   Precision: 0.9859
#   Recall:    0.8433
#   MAE:       0.3289
#   RMSE:      0.7467
#
# Per-Class Metrics:
#   Class                 F1  Precision   Recall
#   --------------- -------- ---------- --------
#   Hartebeest        0.9088     0.9254   0.8927
#   Buffalo           0.9184     0.9752   0.8678
#   Kob               0.8895     0.9379   0.8459
#   Warthog           0.6846     0.9273   0.5426
#   Waterbuck         0.5641     0.9706   0.3976
#   Elephant          0.8425     0.9622   0.7493
# ======================================================================
#
# Grad accum steps:  8
# Total batch size:  16
# LENGTH OF DATA LOADER: 890
# Epoch: [1]  [  0/890]  eta: 0:30:14  lr: 0.000010  class_error: 0.00  loss: 2.3559 (2.3559)  loss_ce: 0.3406 (0.3406)  loss_bbox: 0.0465 (0.0465)  loss_giou: 0.1726 (0.1726)  loss_ce_0: 0.3823 (0.3823)  loss_bbox_0: 0.0426 (0.0426)  loss_giou_0: 0.1657 (0.1657)  loss_ce_1: 0.3274 (0.3274)  loss_bbox_1: 0.0453 (0.0453)  loss_giou_1: 0.1730 (0.1730)  loss_ce_enc: 0.4014 (0.4014)  loss_bbox_enc: 0.0559 (0.0559)  loss_giou_enc: 0.2027 (0.2027)  loss_ce_unscaled: 0.3406 (0.3406)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0093 (0.0093)  loss_giou_unscaled: 0.0863 (0.0863)  cardinality_error_unscaled: 478.5000 (478.5000)  loss_ce_0_unscaled: 0.3823 (0.3823)  loss_bbox_0_unscaled: 0.0085 (0.0085)  loss_giou_0_unscaled: 0.0829 (0.0829)  cardinality_error_0_unscaled: 473.0000 (473.0000)  loss_ce_1_unscaled: 0.3274 (0.3274)  loss_bbox_1_unscaled: 0.0091 (0.0091)  loss_giou_1_unscaled: 0.0865 (0.0865)  cardinality_error_1_unscaled: 630.5000 (630.5000)  loss_ce_enc_unscaled: 0.4014 (0.4014)  loss_bbox_enc_unscaled: 0.0112 (0.0112)  loss_giou_enc_unscaled: 0.1013 (0.1013)  cardinality_error_enc_unscaled: 595.5000 (595.5000)  time: 2.0383  data: 0.9432  max mem: 13413
# Epoch: [1]  [ 10/890]  eta: 0:13:45  lr: 0.000010  class_error: 100.00  loss: 3.0328 (2.5553)  loss_ce: 0.4091 (0.3667)  loss_bbox: 0.0465 (0.0476)  loss_giou: 0.2284 (0.2075)  loss_ce_0: 0.4232 (0.3823)  loss_bbox_0: 0.0426 (0.0463)  loss_giou_0: 0.2240 (0.2075)  loss_ce_1: 0.4158 (0.3681)  loss_bbox_1: 0.0453 (0.0472)  loss_giou_1: 0.2222 (0.2067)  loss_ce_enc: 0.4583 (0.3979)  loss_bbox_enc: 0.0559 (0.0528)  loss_giou_enc: 0.3036 (0.2248)  loss_ce_unscaled: 0.4091 (0.3667)  class_error_unscaled: 0.0000 (30.3030)  loss_bbox_unscaled: 0.0093 (0.0095)  loss_giou_unscaled: 0.1142 (0.1037)  cardinality_error_unscaled: 3896.5000 (3147.6364)  loss_ce_0_unscaled: 0.4232 (0.3823)  loss_bbox_0_unscaled: 0.0085 (0.0093)  loss_giou_0_unscaled: 0.1120 (0.1038)  cardinality_error_0_unscaled: 3876.0000 (3112.0000)  loss_ce_1_unscaled: 0.4158 (0.3681)  loss_bbox_1_unscaled: 0.0091 (0.0094)  loss_giou_1_unscaled: 0.1111 (0.1034)  cardinality_error_1_unscaled: 3898.0000 (3212.6818)  loss_ce_enc_unscaled: 0.4583 (0.3979)  loss_bbox_enc_unscaled: 0.0112 (0.0106)  loss_giou_enc_unscaled: 0.1518 (0.1124)  cardinality_error_enc_unscaled: 3898.0000 (3161.1818)  time: 0.9377  data: 0.1002  max mem: 13413
# Epoch: [1]  [ 20/890]  eta: 0:13:02  lr: 0.000010  class_error: 100.00  loss: 2.1393 (2.0691)  loss_ce: 0.3453 (0.2879)  loss_bbox: 0.0372 (0.0440)  loss_giou: 0.1667 (0.1698)  loss_ce_0: 0.3457 (0.2994)  loss_bbox_0: 0.0372 (0.0440)  loss_giou_0: 0.1613 (0.1711)  loss_ce_1: 0.3469 (0.2902)  loss_bbox_1: 0.0376 (0.0435)  loss_giou_1: 0.1635 (0.1689)  loss_ce_enc: 0.3383 (0.3251)  loss_bbox_enc: 0.0364 (0.0452)  loss_giou_enc: 0.2203 (0.1799)  loss_ce_unscaled: 0.3453 (0.2879)  class_error_unscaled: 0.0000 (39.6825)  loss_bbox_unscaled: 0.0074 (0.0088)  loss_giou_unscaled: 0.0833 (0.0849)  cardinality_error_unscaled: 3892.5000 (3267.6190)  loss_ce_0_unscaled: 0.3457 (0.2994)  loss_bbox_0_unscaled: 0.0074 (0.0088)  loss_giou_0_unscaled: 0.0806 (0.0856)  cardinality_error_0_unscaled: 3835.0000 (3255.5952)  loss_ce_1_unscaled: 0.3469 (0.2902)  loss_bbox_1_unscaled: 0.0075 (0.0087)  loss_giou_1_unscaled: 0.0818 (0.0845)  cardinality_error_1_unscaled: 3895.0000 (3340.0476)  loss_ce_enc_unscaled: 0.3383 (0.3251)  loss_bbox_enc_unscaled: 0.0073 (0.0090)  loss_giou_enc_unscaled: 0.1102 (0.0900)  cardinality_error_enc_unscaled: 3897.5000 (3341.1667)  time: 0.8427  data: 0.0155  max mem: 13413
# Epoch: [1]  [ 30/890]  eta: 0:12:48  lr: 0.000010  class_error: 0.00  loss: 2.4290 (2.3209)  loss_ce: 0.3635 (0.3136)  loss_bbox: 0.0379 (0.0495)  loss_giou: 0.1621 (0.1957)  loss_ce_0: 0.3851 (0.3315)  loss_bbox_0: 0.0390 (0.0496)  loss_giou_0: 0.1627 (0.1975)  loss_ce_1: 0.3684 (0.3152)  loss_bbox_1: 0.0362 (0.0490)  loss_giou_1: 0.1635 (0.1951)  loss_ce_enc: 0.4005 (0.3567)  loss_bbox_enc: 0.0517 (0.0539)  loss_giou_enc: 0.2259 (0.2137)  loss_ce_unscaled: 0.3635 (0.3136)  class_error_unscaled: 0.0000 (33.3333)  loss_bbox_unscaled: 0.0076 (0.0099)  loss_giou_unscaled: 0.0811 (0.0979)  cardinality_error_unscaled: 3892.5000 (3150.9194)  loss_ce_0_unscaled: 0.3851 (0.3315)  loss_bbox_0_unscaled: 0.0078 (0.0099)  loss_giou_0_unscaled: 0.0814 (0.0987)  cardinality_error_0_unscaled: 3835.0000 (3169.6935)  loss_ce_1_unscaled: 0.3684 (0.3152)  loss_bbox_1_unscaled: 0.0072 (0.0098)  loss_giou_1_unscaled: 0.0818 (0.0975)  cardinality_error_1_unscaled: 3895.0000 (3255.8065)  loss_ce_enc_unscaled: 0.4005 (0.3567)  loss_bbox_enc_unscaled: 0.0103 (0.0108)  loss_giou_enc_unscaled: 0.1130 (0.1068)  cardinality_error_enc_unscaled: 3896.0000 (3273.6935)  time: 0.8697  data: 0.0154  max mem: 13413
# Epoch: [1]  [ 40/890]  eta: 0:12:31  lr: 0.000010  class_error: 0.00  loss: 3.1216 (2.4957)  loss_ce: 0.4182 (0.3361)  loss_bbox: 0.0676 (0.0539)  loss_giou: 0.2686 (0.2124)  loss_ce_0: 0.4303 (0.3479)  loss_bbox_0: 0.0587 (0.0538)  loss_giou_0: 0.2559 (0.2124)  loss_ce_1: 0.4118 (0.3368)  loss_bbox_1: 0.0664 (0.0536)  loss_giou_1: 0.2563 (0.2121)  loss_ce_enc: 0.4578 (0.3787)  loss_bbox_enc: 0.0788 (0.0603)  loss_giou_enc: 0.3200 (0.2376)  loss_ce_unscaled: 0.4182 (0.3361)  class_error_unscaled: 0.0000 (27.6423)  loss_bbox_unscaled: 0.0135 (0.0108)  loss_giou_unscaled: 0.1343 (0.1062)  cardinality_error_unscaled: 3626.0000 (3109.4756)  loss_ce_0_unscaled: 0.4303 (0.3479)  loss_bbox_0_unscaled: 0.0117 (0.0108)  loss_giou_0_unscaled: 0.1280 (0.1062)  cardinality_error_0_unscaled: 3432.5000 (3115.2195)  loss_ce_1_unscaled: 0.4118 (0.3368)  loss_bbox_1_unscaled: 0.0133 (0.0107)  loss_giou_1_unscaled: 0.1282 (0.1061)  cardinality_error_1_unscaled: 3842.5000 (3214.8780)  loss_ce_enc_unscaled: 0.4578 (0.3787)  loss_bbox_enc_unscaled: 0.0158 (0.0121)  loss_giou_enc_unscaled: 0.1600 (0.1188)  cardinality_error_enc_unscaled: 3639.0000 (3238.6585)  time: 0.8672  data: 0.0156  max mem: 13413
# Epoch: [1]  [ 50/890]  eta: 0:12:15  lr: 0.000010  class_error: 0.00  loss: 3.1068 (2.5439)  loss_ce: 0.3957 (0.3405)  loss_bbox: 0.0627 (0.0571)  loss_giou: 0.2686 (0.2171)  loss_ce_0: 0.4043 (0.3534)  loss_bbox_0: 0.0678 (0.0574)  loss_giou_0: 0.2659 (0.2182)  loss_ce_1: 0.3939 (0.3416)  loss_bbox_1: 0.0641 (0.0569)  loss_giou_1: 0.2569 (0.2170)  loss_ce_enc: 0.4312 (0.3826)  loss_bbox_enc: 0.0788 (0.0630)  loss_giou_enc: 0.2932 (0.2393)  loss_ce_unscaled: 0.3957 (0.3405)  class_error_unscaled: 0.0000 (24.1830)  loss_bbox_unscaled: 0.0125 (0.0114)  loss_giou_unscaled: 0.1343 (0.1085)  cardinality_error_unscaled: 2656.0000 (3101.1275)  loss_ce_0_unscaled: 0.4043 (0.3534)  loss_bbox_0_unscaled: 0.0136 (0.0115)  loss_giou_0_unscaled: 0.1329 (0.1091)  cardinality_error_0_unscaled: 3183.0000 (3129.3725)  loss_ce_1_unscaled: 0.3939 (0.3416)  loss_bbox_1_unscaled: 0.0128 (0.0114)  loss_giou_1_unscaled: 0.1285 (0.1085)  cardinality_error_1_unscaled: 2993.0000 (3215.8922)  loss_ce_enc_unscaled: 0.4312 (0.3826)  loss_bbox_enc_unscaled: 0.0158 (0.0126)  loss_giou_enc_unscaled: 0.1466 (0.1197)  cardinality_error_enc_unscaled: 3351.5000 (3256.9902)  time: 0.8483  data: 0.0153  max mem: 13413

# %% [markdown]
# ### Evaluación

# %%
eval_cfg = OmegaConf.create({
    'data': {
        'images_root': 'data-delplanque/test',
        'gt_points_csv': 'data-delplanque/test.csv',
    },
    'inference': {
        'device': 'cuda',
        'checkpoint_path': './outputs/rfdetr_large_stage2/checkpoint_best_total.pth',
        'threshold': CONF_THRESHOLD_STAGE2,
        'batch_size': 16,
        'output_path': './results/rfdetr_large',
        'detections_csv': 'rfdetr_stage2_detections.csv',
    },
    'metrics': {
        'radius': MATCH_RADIUS,
        'class_map': None,
    },
})

# %%
checkpoint = torch.load(eval_cfg.inference.checkpoint_path, weights_only=False)
state_dict = checkpoint.get('model', checkpoint.get('ema_model'))
num_classes = state_dict['class_embed.weight'].shape[0]

model_eval = RFDETRLarge()
model_eval.model.reinitialize_detection_head(num_classes)
model_eval.model.model.load_state_dict(state_dict, strict=True)
model_eval.model.model.to(eval_cfg.inference.device).eval()

stitcher = SimpleStitcher(
    model=model_eval.model.model,
    patch_size=PATCH_SIZE,
    overlap=0,
    batch_size=eval_cfg.inference.batch_size,
    confidence_threshold=eval_cfg.inference.threshold,
    device=eval_cfg.inference.device,
    label_offset=0,
)
# Out:
# Loading pretrain weights

# %%
images_root = Path(eval_cfg.data.images_root)
image_files = sorted(
    list(images_root.glob('*.jpg'))
    + list(images_root.glob('*.JPG'))
    + list(images_root.glob('*.png'))
    + list[Path](images_root.glob('*.PNG'))
)

transform = A.Compose([
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

output_dir = Path(eval_cfg.inference.output_path)
output_dir.mkdir(parents=True, exist_ok=True)
all_detections = []

for img_path in tqdm(image_files, desc='Inference'):
    image = Image.open(img_path).convert('RGB')
    image_tensor = transform(image=np.array(image))['image']
    detections = stitcher(image_tensor)

    for i in range(len(detections['scores'])):
        all_detections.append({
            'images': img_path.name,
            'x': float(detections['boxes'][i, 0]),
            'y': float(detections['boxes'][i, 1]),
            'x_max': float(detections['boxes'][i, 2]),
            'y_max': float(detections['boxes'][i, 3]),
            'labels': int(detections['labels'][i]),
            'scores': float(detections['scores'][i]),
        })

pd.DataFrame(all_detections).to_csv(output_dir / eval_cfg.inference.detections_csv, index=False)
print('Saved', len(all_detections), 'detections to', output_dir / eval_cfg.inference.detections_csv)
# Out:
# Inference:   0%|          | 0/258 [00:00<?, ?it/s]UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
# Inference: 100%|██████████| 258/258 [04:35<00:00,  1.07s/it]
# Saved 2285 detections to results/rfdetr_large/rfdetr_stage2_detections.csv

# %%
points_path = output_dir / 'rfdetr_stage2_detections_points.csv'
points_df = convert_bbox_csv_to_points(
    output_dir / eval_cfg.inference.detections_csv,
    points_path,
)
print('Converted', len(points_df), 'detections to points ->', points_path)
points_df.head()
# Out:
# Converted 2285 detections to points -> results/rfdetr_large/rfdetr_stage2_detections_points.csv
#                                          images            x            y  \
# 0  01802f75da35434ab373569fffc1fd65a3417aef.JPG  5246.357422  3558.076172
# 1  01802f75da35434ab373569fffc1fd65a3417aef.JPG  5399.695557  3471.771118
# 2  01802f75da35434ab373569fffc1fd65a3417aef.JPG  5281.511963  3608.711914
# 3  01802f75da35434ab373569fffc1fd65a3417aef.JPG  5362.650635  3534.472168
# 4  01802f75da35434ab373569fffc1fd65a3417aef.JPG  5394.881836  3561.778320
#
#    labels    scores
# 0       6  0.777562
# 1       6  0.838995
# 2       6  0.781437
# 3       6  0.842959
# 4       6  0.537771

# %%
stage2_metrics = evaluate_points_from_csv(
    gt_csv=eval_cfg.data.gt_points_csv,
    detections_csv=output_dir / 'rfdetr_stage2_detections_points.csv',
    class_map_path=eval_cfg.metrics.class_map,
    radius=eval_cfg.metrics.radius,
)
stage2_metrics['overall']
# Out:
# {'precision': 0.8892778993435448,
#  'recall': 0.8838625489343193,
#  'f1_score': 0.8865619546247818,
#  'mae': 1.2248062015503876,
#  'rmse': 3.096634832656525,
#  'mse': 9.589147286821705,
#  'accuracy': np.float64(0.937992125984252)}
